# %% [markdown]
# Create spark session

# %%
from pyspark import SparkContext
from pyspark.sql.session import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %% [markdown]
# Load data set

# %%
df = spark.read.format("csv").option("header", "false").load('/Users/hyy/Desktop/Columbia/E 4571/Project/Final/ratings_Electronics.csv').cache()

# %% [markdown]
# Change index name of the data set

# %%
df = df.select(df._c0.alias("userId"), df._c1.alias("itemId"), df._c2.alias("rating"), df._c3.alias("timestamp"))
df.show(10)
# Out:
# +--------------+----------+------+----------+
# |        userId|    itemId|rating| timestamp|
# +--------------+----------+------+----------+
# | AKM1MP6P0OYPR|0132793040|   5.0|1365811200|
# |A2CX7LUOHB2NDG|0321732944|   5.0|1341100800|
# |A2NWSAGRHCP8N5|0439886341|   1.0|1367193600|
# |A2WNBOD3WNDNKT|0439886341|   3.0|1374451200|
# |A1GI0U4ZRJA8WN|0439886341|   1.0|1334707200|
# |A1QGNMC6O1VW39|0511189877|   5.0|1397433600|
# |A3J3BRHTDRFJ2G|0511189877|   2.0|1397433600|
# |A2TY0BTJOTENPG|0511189877|   5.0|1395878400|
# |A34ATBPOK6HCHY|0511189877|   5.0|1395532800|
# | A89DO69P0XZ27|0511189877|   5.0|1395446400|
# +--------------+----------+------+----------+
# only showing top 10 rows

# %% [markdown]
# Function used to control sparsity of the data set

# %%
def calculate_sparsity(itemlimit, userlimit, df):
    product = df.groupBy("itemId").count()
    product_filter = product.filter(product['count'] > itemlimit)
    Data = df.join(product_filter, ['itemId'], 'leftsemi')
    
    user = Data.groupBy("userId").count()
    user_filter = user.filter(user['count'] > userlimit)
    DF = Data.join(user_filter, ['userId'], 'leftsemi')
    
    available = DF.count()
    product_total = DF.select("itemId").distinct().count()
    user_total = DF.select("userId").distinct().count()
    
    print("available rating: " + str(available))
    print("distinct product: " + str(product_total))
    print("distinct user: " + str(user_total))
    
    result = (float(available)/(float(product_total) * float(user_total)))*100
    print(result)
    
    return DF

# %% [markdown]
# We choose the subset that user rated more twice and product was rated more than twice

# %%
from pyspark.sql.functions import udf, col, regexp_replace
df=calculate_sparsity(2,2,df).cache()
# Out:
# available rating: 3374805
# distinct product: 208371
# distinct user: 615996
# 0.002629259887833436

# %% [markdown]
# Change the product id into int value

# %%
from pyspark.ml.feature import OneHotEncoder, StringIndexer
stringIndexer = StringIndexer(inputCol="itemId", outputCol="ProductIndex")
user = stringIndexer.fit(df)
indexed = user.transform(df).cache()

# %% [markdown]
# Change the user id into int value

# %%
from pyspark.sql.types import *
indexed_distinct=indexed.select("userId").distinct()
User_id = spark.createDataFrame(indexed_distinct.rdd.map(lambda x: x[0]).zipWithIndex(), StructType([StructField("userId", StringType(), True),StructField("User_ID", IntegerType(), True)])).cache()

# %%
joined=indexed.join(User_id,indexed.userId==User_id.userId).cache()

# %% [markdown]
# Data cleaning process

# %%
def inte(f):
    return int(f)

inte_udf = udf(inte)

rating_data = joined.withColumn('Product_ID', inte_udf(col("ProductIndex")))
rating_data = rating_data.withColumn("Product_ID", rating_data["Product_ID"].cast(IntegerType()))
rating_data = rating_data.withColumn("rating", rating_data["rating"].cast(FloatType()))
rating_cleaned = rating_data.select('User_ID', 'Product_ID', 'rating')

# %%
rating_cleaned.show(10)
# Out:
# +-------+----------+------+
# |User_ID|Product_ID|rating|
# +-------+----------+------+
# |      0|     13093|   4.0|
# |      0|     10620|   5.0|
# |      0|        53|   5.0|
# |      1|      2208|   5.0|
# |      1|     38247|   5.0|
# |      1|      1857|   5.0|
# |      1|     45751|   4.0|
# |      1|     33783|   2.0|
# |      1|      5416|   5.0|
# |      2|     14873|   5.0|
# +-------+----------+------+
# only showing top 10 rows

# %% [markdown]
# Split the data set into train, validation and test set with 60%,20%,20% respectively

# %%
train_rdd, valid_rdd, test_rdd = rating_cleaned.rdd.randomSplit(weights=[6, 2, 2], seed=0)
train_df = train_rdd.toDF()
valid_df = valid_rdd.toDF()
test_df = test_rdd.toDF().cache()

# %% [markdown]
# In the baseline model, we use both train set and validation set as training data

# %%
train_valid_df=train_df.union(valid_df).cache()

# %% [markdown]
# Calculate the rating mean of the whole training data

# %%
mean=train_valid_df.select('rating').groupBy().avg("rating").take(1)[0][0]
mean
# Out:
# 4.159511466811338

# %% [markdown]
# Calculate the user bias

# %%
user_bias=train_valid_df.groupBy("User_ID").avg('rating')
user_bias=user_bias.select('User_ID',(((user_bias['avg(rating)'])-mean).alias("user_bias"))).cache()
user_bias.orderBy("User_ID").show(10)
# Out:
# +-------+--------------------+
# |User_ID|           user_bias|
# +-------+--------------------+
# |      0|  0.5071551998553288|
# |      1|  0.8404885331886618|
# |      2| -0.4928448001446717|
# |      3|  0.8404885331886618|
# |      4|  0.8404885331886618|
# |      5|  0.8404885331886618|
# |      6|-0.32617813347800473|
# |      7| 0.09048853318866179|
# |      8| -0.6595114668113382|
# |      9|  0.8404885331886618|
# +-------+--------------------+
# only showing top 10 rows

# %% [markdown]
# Calculate the product bias

# %%
item_bias=train_valid_df.groupBy("Product_ID").avg('rating')
item_bias=item_bias.select('Product_ID',(((item_bias['avg(rating)'])-mean).alias("item_bias"))).cache()
item_bias.orderBy("Product_ID").show(10)
# Out:
# +----------+-------------------+
# |Product_ID|          item_bias|
# +----------+-------------------+
# |         0|0.40516743227123087|
# |         1|-0.1884565409177026|
# |         2| 0.6097337101880997|
# |         3| 0.6250537948461652|
# |         4| 0.4643045007123421|
# |         5|0.23327605755513314|
# |         6| 0.2898029308380252|
# |         7|0.47174355058229267|
# |         8|0.42012370879443406|
# |         9| 0.2307535101471867|
# +----------+-------------------+
# only showing top 10 rows

# %% [markdown]
# Find the top 20 popular products according to the product bias

# %%
popular_item=item_bias.orderBy('item_bias',ascending=False).select('Product_ID').take(20)
popular_item_id=[]
for i in range(len(popular_item)):
    popular_item_id.append(popular_item[i][0])
popular_item_id
# Out:
# [128593,
#  167071,
#  93983,
#  114290,
#  143820,
#  70175,
#  78309,
#  70528,
#  113000,
#  98225,
#  153851,
#  69795,
#  146193,
#  160204,
#  74848,
#  99084,
#  118587,
#  158828,
#  175993,
#  119492]

# %%
from pyspark.sql.functions import col, udf, array, collect_list
train_groupby_item = train_df.groupBy("User_ID").agg(collect_list("Product_ID")).orderBy('User_ID').cache()
train_list=train_groupby_item.take(train_groupby_item.count())
train_list
# Out:
# [Row(User_ID=0, collect_list(Product_ID)=[13093, 10620]),
#  Row(User_ID=1, collect_list(Product_ID)=[38247]),
#  Row(User_ID=2, collect_list(Product_ID)=[14873]),
#  Row(User_ID=3, collect_list(Product_ID)=[20443, 17759, 264]),
#  Row(User_ID=5, collect_list(Product_ID)=[26388, 30]),
#  Row(User_ID=6, collect_list(Product_ID)=[29881, 30026, 4215, 102304, 48013, 6807, 164028, 107023, 8387, 4411]),
#  Row(User_ID=7, collect_list(Product_ID)=[37380, 2645, 742, 195645]),
#  Row(User_ID=8, collect_list(Product_ID)=[52041, 40208]),
#  Row(User_ID=9, collect_list(Product_ID)=[14144]),
#  Row(User_ID=10, collect_list(Product_ID)=[59827, 85, 37341]),
#  Row(User_ID=11, collect_list(Product_ID)=[144341, 5497, 112311]),
#  Row(User_ID=12, collect_list(Product_ID)=[394, 64758, 114677]),
#  Row(User_ID=13, collect_list(Product_ID)=[24250, 1158]),
#  Row(User_ID=14, collect_list(Product_ID)=[1917]),
#  Row(User_ID=15, collect_list(Product_ID)=[138885, 27926]),
#  Row(User_ID=16, collect_list(Product_ID)=[24366]),
#  Row(User_ID=17, collect_list(Product_ID)=[4382, 79, 2478, 48965, 77619, 433, 191, 2351, 13673, 71569, 2118, 48, 25451, 827, 3337, 31, 91, 24648, 11566, 12469, 68645, 138702]),
#  Row(User_ID=18, collect_list(Product_ID)=[940, 3836]),
#  Row(User_ID=19, collect_list(Product_ID)=[95212, 1112, 15514, 175523, 178162, 17725, 10173, 820]),
#  Row(User_ID=20, collect_list(Product_ID)=[371, 484, 4006]),
#  Row(User_ID=21, collect_list(Product_ID)=[64710]),
#  Row(User_ID=22, collect_list(Product_ID)=[23791, 28490]),
#  Row(User_ID=23, collect_list(Product_ID)=[14260, 72331, 1325]),
#  Row(User_ID=24, collect_list(Product_ID)=[52, 6804, 53, 9477]),
#  Row(User_ID=25, collect_list(Product_ID)=[28605, 19152]),
#  Row(User_ID=26, collect_list(Product_ID)=[13, 106, 2510]),
#  Row(User_ID=27, collect_list(Product_ID)=[384, 56465, 79159, 59876]),
#  Row(User_ID=28, collect_list(Product_ID)=[13561, 51603, 19626, 226]),
#  Row(User_ID=29, collect_list(Product_ID)=[6840, 5530, 553, 3, 22017]),
#  Row(User_ID=30, collect_list(Product_ID)=[866, 3658, 101776, 1343]),
#  Row(User_ID=31, collect_list(Product_ID)=[660, 8287]),
#  Row(User_ID=32, collect_list(Product_ID)=[15170, 280, 16076]),
#  Row(User_ID=33, collect_list(Product_ID)=[504, 9008, 50326, 26598, 5767, 219]),
#  Row(User_ID=34, collect_list(Product_ID)=[16568]),
#  Row(User_ID=35, collect_list(Product_ID)=[5249, 101, 164203, 19, 30754]),
#  Row(User_ID=36, collect_list(Product_ID)=[11, 145, 34, 286]),
#  Row(User_ID=37, collect_list(Product_ID)=[6515, 10417]),
#  Row(User_ID=38, collect_list(Product_ID)=[2020, 503, 128]),
#  Row(User_ID=39, collect_list(Product_ID)=[127132, 69031]),
#  Row(User_ID=40, collect_list(Product_ID)=[11879, 1033]),
#  Row(User_ID=41, collect_list(Product_ID)=[6417, 242]),
#  Row(User_ID=42, collect_list(Product_ID)=[18819, 2248]),
#  Row(User_ID=44, collect_list(Product_ID)=[4519, 3430, 2118, 112, 296]),
#  Row(User_ID=45, collect_list(Product_ID)=[2029, 825]),
#  Row(User_ID=46, collect_list(Product_ID)=[178, 10445]),
#  Row(User_ID=47, collect_list(Product_ID)=[6448, 23335, 3594]),
#  Row(User_ID=48, collect_list(Product_ID)=[27391, 2076, 6512]),
#  Row(User_ID=49, collect_list(Product_ID)=[8561, 198752, 172840]),
#  Row(User_ID=50, collect_list(Product_ID)=[107, 67, 62, 277, 6114]),
#  Row(User_ID=51, collect_list(Product_ID)=[14455, 19971]),
#  Row(User_ID=52, collect_list(Product_ID)=[9126, 2847]),
#  Row(User_ID=53, collect_list(Product_ID)=[4433, 203158]),
#  Row(User_ID=54, collect_list(Product_ID)=[3721]),
#  Row(User_ID=55, collect_list(Product_ID)=[419, 31099, 18025, 37, 132249, 1449, 9445, 169779, 44, 44484, 9889, 51736, 697, 1122, 62345, 25935, 7, 1571, 679, 62, 57195, 36103, 1580, 34632, 80317, 28020, 343, 11860, 34325, 25036, 8353, 41234]),
#  Row(User_ID=56, collect_list(Product_ID)=[13764, 444]),
#  Row(User_ID=57, collect_list(Product_ID)=[4085]),
#  Row(User_ID=58, collect_list(Product_ID)=[1886, 56, 990]),
#  Row(User_ID=59, collect_list(Product_ID)=[686]),
#  Row(User_ID=60, collect_list(Product_ID)=[32733, 26499]),
#  Row(User_ID=61, collect_list(Product_ID)=[79, 1224, 16472, 124029, 17613, 10866, 28603, 14100, 54973, 6017, 86692, 9491, 152182]),
#  Row(User_ID=62, collect_list(Product_ID)=[47030, 198, 548]),
#  Row(User_ID=63, collect_list(Product_ID)=[2755, 1733, 5, 1986, 148582, 10013, 19203, 42, 2569, 219]),
#  Row(User_ID=64, collect_list(Product_ID)=[47382, 38962, 75842]),
#  Row(User_ID=65, collect_list(Product_ID)=[7473]),
#  Row(User_ID=66, collect_list(Product_ID)=[4041, 72974]),
#  Row(User_ID=67, collect_list(Product_ID)=[32, 151052]),
#  Row(User_ID=68, collect_list(Product_ID)=[11615, 12290, 32472, 1409]),
#  Row(User_ID=69, collect_list(Product_ID)=[6576, 237, 41]),
#  Row(User_ID=70, collect_list(Product_ID)=[5315]),
#  Row(User_ID=71, collect_list(Product_ID)=[24312]),
#  Row(User_ID=72, collect_list(Product_ID)=[14, 205003]),
#  Row(User_ID=73, collect_list(Product_ID)=[3284]),
#  Row(User_ID=74, collect_list(Product_ID)=[801, 412, 12689]),
#  Row(User_ID=75, collect_list(Product_ID)=[46674, 6402, 4538, 17999, 3532, 153885]),
#  Row(User_ID=76, collect_list(Product_ID)=[3184]),
#  Row(User_ID=77, collect_list(Product_ID)=[2714, 31]),
#  Row(User_ID=78, collect_list(Product_ID)=[45725, 22901, 12822]),
#  Row(User_ID=79, collect_list(Product_ID)=[33011, 233]),
#  Row(User_ID=80, collect_list(Product_ID)=[62462, 815]),
#  Row(User_ID=81, collect_list(Product_ID)=[128644, 66779, 33658, 1814, 12480]),
#  Row(User_ID=82, collect_list(Product_ID)=[10, 1074]),
#  Row(User_ID=83, collect_list(Product_ID)=[45101, 51093, 137624, 337, 3669, 65385, 24840, 69860, 15, 8068, 31881, 67427, 334, 8762, 4616, 7993, 17, 4074, 9249, 47169, 263, 199, 157890, 9719, 159391, 93083, 5399, 127912, 3, 639, 604, 40569, 122431]),
#  Row(User_ID=84, collect_list(Product_ID)=[1145, 13286]),
#  Row(User_ID=85, collect_list(Product_ID)=[21955, 3124]),
#  Row(User_ID=86, collect_list(Product_ID)=[52, 21780, 855, 375]),
#  Row(User_ID=87, collect_list(Product_ID)=[140731, 1834]),
#  Row(User_ID=88, collect_list(Product_ID)=[252, 40890]),
#  Row(User_ID=89, collect_list(Product_ID)=[115630, 6511, 10437, 91]),
#  Row(User_ID=90, collect_list(Product_ID)=[2887, 571]),
#  Row(User_ID=91, collect_list(Product_ID)=[43253, 19]),
#  Row(User_ID=92, collect_list(Product_ID)=[12637, 8960, 113136, 4855]),
#  Row(User_ID=93, collect_list(Product_ID)=[7114, 24553]),
#  Row(User_ID=94, collect_list(Product_ID)=[4845, 995]),
#  Row(User_ID=95, collect_list(Product_ID)=[159067, 29992, 13063]),
#  Row(User_ID=96, collect_list(Product_ID)=[10118, 93875, 20034, 23464]),
#  Row(User_ID=97, collect_list(Product_ID)=[57]),
#  Row(User_ID=98, collect_list(Product_ID)=[38397, 102449]),
#  Row(User_ID=99, collect_list(Product_ID)=[166993, 10108, 38735, 88103, 319]),
#  Row(User_ID=100, collect_list(Product_ID)=[1852, 121636, 99384]),
#  Row(User_ID=101, collect_list(Product_ID)=[18121, 25661, 26381, 12533]),
#  Row(User_ID=102, collect_list(Product_ID)=[4147]),
#  Row(User_ID=103, collect_list(Product_ID)=[133339, 18444]),
#  Row(User_ID=104, collect_list(Product_ID)=[111, 48983, 4702]),
#  Row(User_ID=105, collect_list(Product_ID)=[2203, 1795, 126, 772, 3912]),
#  Row(User_ID=106, collect_list(Product_ID)=[46887, 19911]),
#  Row(User_ID=107, collect_list(Product_ID)=[56800, 11340, 6616]),
#  Row(User_ID=108, collect_list(Product_ID)=[10320, 8308, 158]),
#  Row(User_ID=110, collect_list(Product_ID)=[109, 14215]),
#  Row(User_ID=112, collect_list(Product_ID)=[5043, 475]),
#  Row(User_ID=113, collect_list(Product_ID)=[104430, 7854, 151, 0, 53751, 5753]),
#  Row(User_ID=114, collect_list(Product_ID)=[77424, 31, 21036]),
#  Row(User_ID=115, collect_list(Product_ID)=[13938, 17473, 5433, 350]),
#  Row(User_ID=116, collect_list(Product_ID)=[153296, 123995, 6403, 49834, 1268, 15574, 6955]),
#  Row(User_ID=117, collect_list(Product_ID)=[1398, 91062]),
#  Row(User_ID=119, collect_list(Product_ID)=[46, 602]),
#  Row(User_ID=120, collect_list(Product_ID)=[1107, 1438, 20]),
#  Row(User_ID=121, collect_list(Product_ID)=[36112, 18899]),
#  Row(User_ID=122, collect_list(Product_ID)=[175, 80, 2897]),
#  Row(User_ID=123, collect_list(Product_ID)=[3858, 4670, 6397]),
#  Row(User_ID=125, collect_list(Product_ID)=[13176, 73319, 663, 32, 40472, 9494]),
#  Row(User_ID=126, collect_list(Product_ID)=[28866, 14027, 7798]),
#  Row(User_ID=127, collect_list(Product_ID)=[380, 99, 517, 58]),
#  Row(User_ID=128, collect_list(Product_ID)=[23344, 1345]),
#  Row(User_ID=129, collect_list(Product_ID)=[9, 12, 3701, 3473, 3915, 74]),
#  Row(User_ID=130, collect_list(Product_ID)=[51359, 1580]),
#  Row(User_ID=131, collect_list(Product_ID)=[47473, 37506, 7750, 52502, 27537, 118350, 44514]),
#  Row(User_ID=132, collect_list(Product_ID)=[12546, 895, 486, 95273, 12988, 25574, 5615, 50155, 53560]),
#  Row(User_ID=133, collect_list(Product_ID)=[27689, 50, 25164]),
#  Row(User_ID=134, collect_list(Product_ID)=[109006, 35097, 32408]),
#  Row(User_ID=135, collect_list(Product_ID)=[96945, 36010]),
#  Row(User_ID=136, collect_list(Product_ID)=[2209, 528]),
#  Row(User_ID=137, collect_list(Product_ID)=[5486, 425]),
#  Row(User_ID=138, collect_list(Product_ID)=[10499]),
#  Row(User_ID=139, collect_list(Product_ID)=[22439, 107795, 117, 66168]),
#  Row(User_ID=140, collect_list(Product_ID)=[11461, 176]),
#  Row(User_ID=141, collect_list(Product_ID)=[18433, 68956, 65596]),
#  Row(User_ID=142, collect_list(Product_ID)=[175, 60795, 20644, 9616, 47201]),
#  Row(User_ID=143, collect_list(Product_ID)=[47499]),
#  Row(User_ID=144, collect_list(Product_ID)=[15736]),
#  Row(User_ID=145, collect_list(Product_ID)=[4380, 99]),
#  Row(User_ID=146, collect_list(Product_ID)=[36911, 53475, 2569]),
#  Row(User_ID=147, collect_list(Product_ID)=[25685, 1305, 54368]),
#  Row(User_ID=148, collect_list(Product_ID)=[538]),
#  Row(User_ID=149, collect_list(Product_ID)=[148, 41339, 880]),
#  Row(User_ID=151, collect_list(Product_ID)=[9621, 3233, 57449]),
#  Row(User_ID=152, collect_list(Product_ID)=[974, 207, 5494, 4610]),
#  Row(User_ID=153, collect_list(Product_ID)=[71291, 1208]),
#  Row(User_ID=154, collect_list(Product_ID)=[664, 20802, 12936]),
#  Row(User_ID=155, collect_list(Product_ID)=[33849, 9570, 60921, 23614, 36104]),
#  Row(User_ID=156, collect_list(Product_ID)=[4096, 2829]),
#  Row(User_ID=157, collect_list(Product_ID)=[1072, 8056, 40983]),
#  Row(User_ID=158, collect_list(Product_ID)=[39403]),
#  Row(User_ID=159, collect_list(Product_ID)=[8379, 49967, 858, 98822, 68337, 39043, 11728, 5657, 10371]),
#  Row(User_ID=160, collect_list(Product_ID)=[335, 4428]),
#  Row(User_ID=161, collect_list(Product_ID)=[62314, 2270, 16702, 1882, 27785, 2226, 1390, 19452, 5083, 16556, 22027, 15459, 4070, 35245, 775, 2, 226]),
#  Row(User_ID=162, collect_list(Product_ID)=[92, 6312, 29251, 99306]),
#  Row(User_ID=163, collect_list(Product_ID)=[27804, 528]),
#  Row(User_ID=164, collect_list(Product_ID)=[7318, 2344, 1821]),
#  Row(User_ID=165, collect_list(Product_ID)=[27604, 82240, 16031]),
#  Row(User_ID=166, collect_list(Product_ID)=[131750, 133519, 14370, 73090, 15, 141411, 104598]),
#  Row(User_ID=167, collect_list(Product_ID)=[1007, 1196, 30]),
#  Row(User_ID=168, collect_list(Product_ID)=[76347]),
#  Row(User_ID=169, collect_list(Product_ID)=[36166, 1700]),
#  Row(User_ID=170, collect_list(Product_ID)=[2496, 15, 5143]),
#  Row(User_ID=172, collect_list(Product_ID)=[9773, 11500, 1552, 187, 0, 112, 91]),
#  Row(User_ID=173, collect_list(Product_ID)=[1428, 11146, 159]),
#  Row(User_ID=174, collect_list(Product_ID)=[4614, 138]),
#  Row(User_ID=175, collect_list(Product_ID)=[2297]),
#  Row(User_ID=176, collect_list(Product_ID)=[20920, 434, 25990, 55045]),
#  Row(User_ID=177, collect_list(Product_ID)=[7906, 3092]),
#  Row(User_ID=178, collect_list(Product_ID)=[95158]),
#  Row(User_ID=179, collect_list(Product_ID)=[621, 8987]),
#  Row(User_ID=180, collect_list(Product_ID)=[547, 2863]),
#  Row(User_ID=181, collect_list(Product_ID)=[30566, 23997]),
#  Row(User_ID=182, collect_list(Product_ID)=[2782]),
#  Row(User_ID=183, collect_list(Product_ID)=[4113]),
#  Row(User_ID=184, collect_list(Product_ID)=[10257]),
#  Row(User_ID=185, collect_list(Product_ID)=[132218, 75957, 35650, 126430]),
#  Row(User_ID=186, collect_list(Product_ID)=[2769]),
#  Row(User_ID=187, collect_list(Product_ID)=[84773, 25996]),
#  Row(User_ID=188, collect_list(Product_ID)=[157, 5314, 84799, 59338]),
#  Row(User_ID=189, collect_list(Product_ID)=[674]),
#  Row(User_ID=190, collect_list(Product_ID)=[17261, 30874, 75418, 21538, 1282, 1223, 10557, 297, 8284]),
#  Row(User_ID=191, collect_list(Product_ID)=[386, 30096, 1056]),
#  Row(User_ID=192, collect_list(Product_ID)=[2440, 20530, 3562, 1001]),
#  Row(User_ID=194, collect_list(Product_ID)=[24486]),
#  Row(User_ID=195, collect_list(Product_ID)=[3366, 3847, 37395]),
#  Row(User_ID=196, collect_list(Product_ID)=[46728, 7131, 2555, 2787]),
#  Row(User_ID=197, collect_list(Product_ID)=[1431]),
#  Row(User_ID=198, collect_list(Product_ID)=[143716, 5831, 4095]),
#  Row(User_ID=199, collect_list(Product_ID)=[106452]),
#  Row(User_ID=200, collect_list(Product_ID)=[2721, 36757, 165533, 2002]),
#  Row(User_ID=201, collect_list(Product_ID)=[203, 27323]),
#  Row(User_ID=202, collect_list(Product_ID)=[34411, 33501]),
#  Row(User_ID=203, collect_list(Product_ID)=[4785, 79966, 3421]),
#  Row(User_ID=204, collect_list(Product_ID)=[192, 264]),
#  Row(User_ID=205, collect_list(Product_ID)=[990, 114398, 364]),
#  Row(User_ID=206, collect_list(Product_ID)=[88897, 114518, 519, 34628, 9344, 2141, 16829, 2061, 3829, 10832, 367, 30, 8746]),
#  Row(User_ID=207, collect_list(Product_ID)=[721, 844]),
#  Row(User_ID=208, collect_list(Product_ID)=[991, 36779, 157369, 15616, 12693, 31573, 19496, 28507]),
#  Row(User_ID=209, collect_list(Product_ID)=[1329, 180957]),
#  Row(User_ID=210, collect_list(Product_ID)=[8449, 4089, 82733]),
#  Row(User_ID=211, collect_list(Product_ID)=[30182, 4004, 6963, 3264, 153711, 41423, 705, 12870, 15425, 11017]),
#  Row(User_ID=212, collect_list(Product_ID)=[0, 27468]),
#  Row(User_ID=213, collect_list(Product_ID)=[975]),
#  Row(User_ID=214, collect_list(Product_ID)=[33681, 41228]),
#  Row(User_ID=215, collect_list(Product_ID)=[4522, 503, 6560]),
#  Row(User_ID=216, collect_list(Product_ID)=[79, 7237, 25230, 34363, 91480]),
#  Row(User_ID=217, collect_list(Product_ID)=[1718, 14019]),
#  Row(User_ID=218, collect_list(Product_ID)=[26475]),
#  Row(User_ID=219, collect_list(Product_ID)=[4491]),
#  Row(User_ID=220, collect_list(Product_ID)=[69, 2453, 1369, 55]),
#  Row(User_ID=221, collect_list(Product_ID)=[13820, 16829, 2361, 7316, 39282]),
#  Row(User_ID=222, collect_list(Product_ID)=[1943, 951]),
#  Row(User_ID=223, collect_list(Product_ID)=[1816, 1, 152]),
#  Row(User_ID=224, collect_list(Product_ID)=[938, 2622]),
#  Row(User_ID=225, collect_list(Product_ID)=[362, 12729, 91139, 32028, 2802, 1036, 151985, 32980]),
#  Row(User_ID=226, collect_list(Product_ID)=[13796]),
#  Row(User_ID=227, collect_list(Product_ID)=[52381, 499, 4438, 3034, 13651]),
#  Row(User_ID=228, collect_list(Product_ID)=[24112, 181, 34629, 22034, 1110]),
#  Row(User_ID=229, collect_list(Product_ID)=[371, 95, 11642]),
#  Row(User_ID=230, collect_list(Product_ID)=[933, 14505]),
#  Row(User_ID=231, collect_list(Product_ID)=[155801, 22734, 8841, 110]),
#  Row(User_ID=232, collect_list(Product_ID)=[709, 9576, 459, 11087, 18644, 6090, 433, 8320, 31276, 4409, 1502, 44322]),
#  Row(User_ID=233, collect_list(Product_ID)=[81651]),
#  Row(User_ID=234, collect_list(Product_ID)=[8479, 51011, 49, 94743]),
#  Row(User_ID=235, collect_list(Product_ID)=[72933, 26208]),
#  Row(User_ID=236, collect_list(Product_ID)=[202, 21757, 86, 8384]),
#  Row(User_ID=237, collect_list(Product_ID)=[2077, 141498, 37693, 7801, 83096]),
#  Row(User_ID=238, collect_list(Product_ID)=[137801, 3878, 1384, 33447]),
#  Row(User_ID=239, collect_list(Product_ID)=[16293, 11281, 1]),
#  Row(User_ID=240, collect_list(Product_ID)=[207, 16938, 69527]),
#  Row(User_ID=241, collect_list(Product_ID)=[15093]),
#  Row(User_ID=242, collect_list(Product_ID)=[30703, 1157, 227]),
#  Row(User_ID=243, collect_list(Product_ID)=[29137, 7, 458]),
#  Row(User_ID=244, collect_list(Product_ID)=[2448, 17072, 35311, 121]),
#  Row(User_ID=245, collect_list(Product_ID)=[11, 5328]),
#  Row(User_ID=246, collect_list(Product_ID)=[39575]),
#  Row(User_ID=247, collect_list(Product_ID)=[119629]),
#  Row(User_ID=248, collect_list(Product_ID)=[42]),
#  Row(User_ID=249, collect_list(Product_ID)=[12365, 11097, 5976]),
#  Row(User_ID=250, collect_list(Product_ID)=[14935, 458]),
#  Row(User_ID=251, collect_list(Product_ID)=[60, 11241, 11825, 1312, 4207, 3503]),
#  Row(User_ID=252, collect_list(Product_ID)=[944, 1981]),
#  Row(User_ID=253, collect_list(Product_ID)=[43348, 16245, 20760, 13474, 1183]),
#  Row(User_ID=254, collect_list(Product_ID)=[245, 11184, 19269]),
#  Row(User_ID=255, collect_list(Product_ID)=[1015, 5275, 3054, 143097]),
#  Row(User_ID=256, collect_list(Product_ID)=[45836, 33979]),
#  Row(User_ID=257, collect_list(Product_ID)=[3152, 41335, 5204, 39541]),
#  Row(User_ID=258, collect_list(Product_ID)=[320, 25250, 22500, 45670, 3056, 32422, 59735, 3]),
#  Row(User_ID=259, collect_list(Product_ID)=[9258, 8983, 64]),
#  Row(User_ID=260, collect_list(Product_ID)=[26478, 47162, 219]),
#  Row(User_ID=261, collect_list(Product_ID)=[453, 4020]),
#  Row(User_ID=262, collect_list(Product_ID)=[72952, 17]),
#  Row(User_ID=263, collect_list(Product_ID)=[139, 18207]),
#  Row(User_ID=264, collect_list(Product_ID)=[10167, 40152, 6299, 7899, 7973, 9395, 8923, 66485, 28295, 7012, 114, 7416, 6842, 10355, 848, 30828, 19254, 7605, 528]),
#  Row(User_ID=265, collect_list(Product_ID)=[165856]),
#  Row(User_ID=266, collect_list(Product_ID)=[583, 98108, 63637]),
#  Row(User_ID=267, collect_list(Product_ID)=[10538, 564, 5657]),
#  Row(User_ID=268, collect_list(Product_ID)=[18758, 17305, 5700, 4609, 30563]),
#  Row(User_ID=269, collect_list(Product_ID)=[7225, 52612, 15874]),
#  Row(User_ID=270, collect_list(Product_ID)=[62962, 4886, 6343, 11596, 40060, 105992]),
#  Row(User_ID=271, collect_list(Product_ID)=[44299, 822, 22045, 31853]),
#  Row(User_ID=272, collect_list(Product_ID)=[3354, 24]),
#  Row(User_ID=273, collect_list(Product_ID)=[13614, 29009, 445, 2284, 8447]),
#  Row(User_ID=274, collect_list(Product_ID)=[48265]),
#  Row(User_ID=275, collect_list(Product_ID)=[120260]),
#  Row(User_ID=276, collect_list(Product_ID)=[81672, 742]),
#  Row(User_ID=277, collect_list(Product_ID)=[119961, 158666, 639]),
#  Row(User_ID=278, collect_list(Product_ID)=[3860, 19815, 65]),
#  Row(User_ID=279, collect_list(Product_ID)=[5773, 384, 3587, 608, 617]),
#  Row(User_ID=280, collect_list(Product_ID)=[14, 32545, 9070]),
#  Row(User_ID=281, collect_list(Product_ID)=[80]),
#  Row(User_ID=282, collect_list(Product_ID)=[122180, 158003]),
#  Row(User_ID=283, collect_list(Product_ID)=[91962, 333, 21128, 56860, 69353]),
#  Row(User_ID=284, collect_list(Product_ID)=[1574, 659]),
#  Row(User_ID=285, collect_list(Product_ID)=[15760, 118519]),
#  Row(User_ID=286, collect_list(Product_ID)=[92089, 6790, 51687, 40]),
#  Row(User_ID=287, collect_list(Product_ID)=[50]),
#  Row(User_ID=288, collect_list(Product_ID)=[2452, 6205, 47240]),
#  Row(User_ID=290, collect_list(Product_ID)=[13516, 10942]),
#  Row(User_ID=291, collect_list(Product_ID)=[1867, 42202]),
#  Row(User_ID=292, collect_list(Product_ID)=[118, 18339, 27, 672]),
#  Row(User_ID=293, collect_list(Product_ID)=[2282, 265, 1540, 4507, 77]),
#  Row(User_ID=294, collect_list(Product_ID)=[10, 41, 18726, 319]),
#  Row(User_ID=295, collect_list(Product_ID)=[8230, 1048, 96500]),
#  Row(User_ID=296, collect_list(Product_ID)=[5586, 7437, 26919]),
#  Row(User_ID=298, collect_list(Product_ID)=[38038, 10068, 3940, 22203]),
#  Row(User_ID=299, collect_list(Product_ID)=[25453, 7032]),
#  Row(User_ID=300, collect_list(Product_ID)=[213, 28642, 2278, 414, 1262]),
#  Row(User_ID=301, collect_list(Product_ID)=[69277, 10886, 2269]),
#  Row(User_ID=302, collect_list(Product_ID)=[2028, 295, 103148, 20236, 27398, 186269, 658, 23652]),
#  Row(User_ID=303, collect_list(Product_ID)=[698, 1530, 3095]),
#  Row(User_ID=304, collect_list(Product_ID)=[79890, 7313, 14563, 6824, 399, 28468, 101595, 544, 45095]),
#  Row(User_ID=305, collect_list(Product_ID)=[2106, 102979]),
#  Row(User_ID=306, collect_list(Product_ID)=[78, 363]),
#  Row(User_ID=307, collect_list(Product_ID)=[9967]),
#  Row(User_ID=308, collect_list(Product_ID)=[670, 24393, 2021, 18254]),
#  Row(User_ID=309, collect_list(Product_ID)=[182517, 25067, 43602]),
#  Row(User_ID=310, collect_list(Product_ID)=[204890, 9030, 4307, 575, 170777, 1658]),
#  Row(User_ID=311, collect_list(Product_ID)=[70, 318]),
#  Row(User_ID=312, collect_list(Product_ID)=[3927, 99598, 771, 65210, 4573, 9181, 585, 1013, 137187, 129]),
#  Row(User_ID=313, collect_list(Product_ID)=[10180]),
#  Row(User_ID=314, collect_list(Product_ID)=[420, 1565]),
#  Row(User_ID=315, collect_list(Product_ID)=[2036, 833, 5579]),
#  Row(User_ID=316, collect_list(Product_ID)=[38891, 687, 50165, 13773, 3011, 9940, 8252, 3125, 7718, 2119, 1701]),
#  Row(User_ID=317, collect_list(Product_ID)=[4679, 22067, 59]),
#  Row(User_ID=318, collect_list(Product_ID)=[10970, 117751]),
#  Row(User_ID=319, collect_list(Product_ID)=[1361, 7792]),
#  Row(User_ID=320, collect_list(Product_ID)=[28804]),
#  Row(User_ID=321, collect_list(Product_ID)=[1477, 12065]),
#  Row(User_ID=322, collect_list(Product_ID)=[38354, 5392, 58650, 9364, 122125, 100077]),
#  Row(User_ID=323, collect_list(Product_ID)=[2851, 8777, 11703]),
#  Row(User_ID=324, collect_list(Product_ID)=[32704, 5775, 64]),
#  Row(User_ID=325, collect_list(Product_ID)=[49038, 11131, 311, 67, 61130, 6956, 150, 23514, 17039]),
#  Row(User_ID=326, collect_list(Product_ID)=[5953, 134075, 6399, 463, 287, 34, 32463, 163, 29398]),
#  Row(User_ID=327, collect_list(Product_ID)=[13813, 12810]),
#  Row(User_ID=328, collect_list(Product_ID)=[46557, 132284]),
#  Row(User_ID=329, collect_list(Product_ID)=[598, 3966]),
#  Row(User_ID=330, collect_list(Product_ID)=[938]),
#  Row(User_ID=331, collect_list(Product_ID)=[93040]),
#  Row(User_ID=332, collect_list(Product_ID)=[138691, 34766, 411]),
#  Row(User_ID=333, collect_list(Product_ID)=[629, 5, 686, 2536, 137156, 40]),
#  Row(User_ID=334, collect_list(Product_ID)=[5736, 6752, 17210, 10795]),
#  Row(User_ID=335, collect_list(Product_ID)=[6246, 3183, 2860]),
#  Row(User_ID=336, collect_list(Product_ID)=[5904, 29314]),
#  Row(User_ID=337, collect_list(Product_ID)=[1065, 5297, 17802, 28]),
#  Row(User_ID=338, collect_list(Product_ID)=[3469, 57615, 13692, 58]),
#  Row(User_ID=339, collect_list(Product_ID)=[73599, 30601, 79183, 41522]),
#  Row(User_ID=340, collect_list(Product_ID)=[2470, 14219, 1635, 1661, 188, 4163, 1704]),
#  Row(User_ID=341, collect_list(Product_ID)=[57764, 46996, 151817]),
#  Row(User_ID=342, collect_list(Product_ID)=[6564, 24365, 10559]),
#  Row(User_ID=343, collect_list(Product_ID)=[78535, 205363]),
#  Row(User_ID=344, collect_list(Product_ID)=[96766]),
#  Row(User_ID=345, collect_list(Product_ID)=[605, 2555, 13015, 364]),
#  Row(User_ID=346, collect_list(Product_ID)=[9055, 2]),
#  Row(User_ID=347, collect_list(Product_ID)=[10746, 16511, 7800, 62, 23249]),
#  Row(User_ID=348, collect_list(Product_ID)=[9559, 1076, 1900, 8552, 403, 1901]),
#  Row(User_ID=349, collect_list(Product_ID)=[221, 11682, 5509]),
#  Row(User_ID=350, collect_list(Product_ID)=[6790, 1207]),
#  Row(User_ID=351, collect_list(Product_ID)=[5997, 767, 43929]),
#  Row(User_ID=352, collect_list(Product_ID)=[28672, 23115]),
#  Row(User_ID=353, collect_list(Product_ID)=[38919, 3212, 44316, 61315]),
#  Row(User_ID=354, collect_list(Product_ID)=[566]),
#  Row(User_ID=355, collect_list(Product_ID)=[181, 22591, 22706]),
#  Row(User_ID=356, collect_list(Product_ID)=[1513]),
#  Row(User_ID=357, collect_list(Product_ID)=[3020]),
#  Row(User_ID=358, collect_list(Product_ID)=[6802, 5790]),
#  Row(User_ID=359, collect_list(Product_ID)=[350]),
#  Row(User_ID=360, collect_list(Product_ID)=[2375, 95121, 163]),
#  Row(User_ID=361, collect_list(Product_ID)=[3416, 83, 28]),
#  Row(User_ID=363, collect_list(Product_ID)=[31988, 1707, 22879]),
#  Row(User_ID=364, collect_list(Product_ID)=[2145]),
#  Row(User_ID=365, collect_list(Product_ID)=[23351, 126, 1815, 2659, 40747]),
#  Row(User_ID=366, collect_list(Product_ID)=[15225, 30118, 5469, 8927, 30744]),
#  Row(User_ID=367, collect_list(Product_ID)=[22976, 112463]),
#  Row(User_ID=368, collect_list(Product_ID)=[27682, 136762, 352]),
#  Row(User_ID=369, collect_list(Product_ID)=[23911, 71285, 5724]),
#  Row(User_ID=370, collect_list(Product_ID)=[228, 10219, 923]),
#  Row(User_ID=371, collect_list(Product_ID)=[36954, 518]),
#  Row(User_ID=372, collect_list(Product_ID)=[3452, 91890, 7703]),
#  Row(User_ID=373, collect_list(Product_ID)=[42948, 32305, 132]),
#  Row(User_ID=374, collect_list(Product_ID)=[1498, 74]),
#  Row(User_ID=375, collect_list(Product_ID)=[35]),
#  Row(User_ID=376, collect_list(Product_ID)=[27198, 5224]),
#  Row(User_ID=377, collect_list(Product_ID)=[204, 62, 272]),
#  Row(User_ID=378, collect_list(Product_ID)=[19805, 1441, 1728]),
#  Row(User_ID=379, collect_list(Product_ID)=[24519, 357, 1821]),
#  Row(User_ID=380, collect_list(Product_ID)=[206, 404, 63488]),
#  Row(User_ID=381, collect_list(Product_ID)=[5071, 22475, 70320, 6350]),
#  Row(User_ID=382, collect_list(Product_ID)=[2209, 3624]),
#  Row(User_ID=383, collect_list(Product_ID)=[16973, 2810, 433]),
#  Row(User_ID=384, collect_list(Product_ID)=[2615, 1039, 5652, 1079, 31529, 813]),
#  Row(User_ID=385, collect_list(Product_ID)=[173029, 3]),
#  Row(User_ID=386, collect_list(Product_ID)=[10, 160]),
#  Row(User_ID=387, collect_list(Product_ID)=[37285, 3408, 4969, 6067]),
#  Row(User_ID=388, collect_list(Product_ID)=[2098, 1613, 7575]),
#  Row(User_ID=389, collect_list(Product_ID)=[191772, 1116]),
#  Row(User_ID=390, collect_list(Product_ID)=[79, 27, 4439]),
#  Row(User_ID=391, collect_list(Product_ID)=[2573, 6220, 4422]),
#  Row(User_ID=392, collect_list(Product_ID)=[2551]),
#  Row(User_ID=393, collect_list(Product_ID)=[12]),
#  Row(User_ID=394, collect_list(Product_ID)=[88304]),
#  Row(User_ID=395, collect_list(Product_ID)=[4454, 15818, 43807, 855]),
#  Row(User_ID=396, collect_list(Product_ID)=[768, 527]),
#  Row(User_ID=397, collect_list(Product_ID)=[2890, 109581, 127, 63193, 160, 1591, 28597, 146]),
#  Row(User_ID=398, collect_list(Product_ID)=[32822, 5131]),
#  Row(User_ID=399, collect_list(Product_ID)=[13872, 16044, 7561, 18522, 9521]),
#  Row(User_ID=400, collect_list(Product_ID)=[381, 15935, 186494, 1684, 9189, 49684, 8523, 21836, 5859, 61319, 50800, 23729, 17788, 1269, 872, 199087, 6540, 3372, 1397, 43, 15151, 84614, 82762]),
#  Row(User_ID=401, collect_list(Product_ID)=[1, 43371]),
#  Row(User_ID=403, collect_list(Product_ID)=[12649, 1289, 793]),
#  Row(User_ID=404, collect_list(Product_ID)=[13, 106, 1288]),
#  Row(User_ID=405, collect_list(Product_ID)=[53062]),
#  Row(User_ID=406, collect_list(Product_ID)=[1115, 6, 4]),
#  Row(User_ID=407, collect_list(Product_ID)=[4753]),
#  Row(User_ID=408, collect_list(Product_ID)=[21042]),
#  Row(User_ID=409, collect_list(Product_ID)=[76204, 50687]),
#  Row(User_ID=410, collect_list(Product_ID)=[123, 1550, 4176, 150]),
#  Row(User_ID=411, collect_list(Product_ID)=[1175, 410]),
#  Row(User_ID=412, collect_list(Product_ID)=[3328, 171]),
#  Row(User_ID=413, collect_list(Product_ID)=[3078, 28080]),
#  Row(User_ID=414, collect_list(Product_ID)=[611, 3445, 41025]),
#  Row(User_ID=415, collect_list(Product_ID)=[10]),
#  Row(User_ID=417, collect_list(Product_ID)=[28625, 15, 29060, 19]),
#  Row(User_ID=418, collect_list(Product_ID)=[134, 169958, 6483, 308]),
#  Row(User_ID=419, collect_list(Product_ID)=[24474, 1593, 31907, 54859]),
#  Row(User_ID=420, collect_list(Product_ID)=[11714, 8, 291, 4927]),
#  Row(User_ID=421, collect_list(Product_ID)=[135625, 2111, 1673, 61078, 937]),
#  Row(User_ID=422, collect_list(Product_ID)=[2120]),
#  Row(User_ID=423, collect_list(Product_ID)=[549, 1664]),
#  Row(User_ID=424, collect_list(Product_ID)=[19467, 2090, 3215, 12256]),
#  Row(User_ID=425, collect_list(Product_ID)=[709, 541, 15936]),
#  Row(User_ID=426, collect_list(Product_ID)=[392, 744]),
#  Row(User_ID=427, collect_list(Product_ID)=[1076, 92616, 2337]),
#  Row(User_ID=428, collect_list(Product_ID)=[951, 1863, 97297, 12, 21664, 15528, 11889, 111, 2]),
#  Row(User_ID=429, collect_list(Product_ID)=[8995, 1379, 306, 2630, 141, 24]),
#  Row(User_ID=430, collect_list(Product_ID)=[3697, 13227, 29840]),
#  Row(User_ID=431, collect_list(Product_ID)=[36946, 162, 65186, 110050, 18365, 3882]),
#  Row(User_ID=432, collect_list(Product_ID)=[2974, 72437, 26558, 8241]),
#  Row(User_ID=433, collect_list(Product_ID)=[29722, 161058, 47365, 2376, 28530]),
#  Row(User_ID=434, collect_list(Product_ID)=[710, 10045]),
#  Row(User_ID=436, collect_list(Product_ID)=[5322, 30515, 2268]),
#  Row(User_ID=437, collect_list(Product_ID)=[6990, 62970, 23826]),
#  Row(User_ID=438, collect_list(Product_ID)=[95, 117, 5376]),
#  Row(User_ID=439, collect_list(Product_ID)=[1344, 3424]),
#  Row(User_ID=440, collect_list(Product_ID)=[161743, 58081, 11517, 154172, 27767, 167740, 2857, 4061, 38363, 135567]),
#  Row(User_ID=441, collect_list(Product_ID)=[27496, 15552, 1870, 109751, 572, 1695, 13808, 18852, 13766, 18528, 168708, 3709, 1998, 1892, 66874, 20747, 2, 79646, 406]),
#  Row(User_ID=442, collect_list(Product_ID)=[20765, 4324, 3405]),
#  Row(User_ID=443, collect_list(Product_ID)=[207, 20719]),
#  Row(User_ID=444, collect_list(Product_ID)=[22983, 1706]),
#  Row(User_ID=445, collect_list(Product_ID)=[2838]),
#  Row(User_ID=446, collect_list(Product_ID)=[13883, 91280, 7421]),
#  Row(User_ID=447, collect_list(Product_ID)=[12125, 8167]),
#  Row(User_ID=448, collect_list(Product_ID)=[10426, 1037, 28568]),
#  Row(User_ID=449, collect_list(Product_ID)=[5298, 236, 6156]),
#  Row(User_ID=450, collect_list(Product_ID)=[126875, 267]),
#  Row(User_ID=451, collect_list(Product_ID)=[8847, 105774]),
#  Row(User_ID=452, collect_list(Product_ID)=[543, 138926]),
#  Row(User_ID=453, collect_list(Product_ID)=[1628]),
#  Row(User_ID=454, collect_list(Product_ID)=[44146, 70861, 1831, 32691, 39, 527, 1055, 65796]),
#  Row(User_ID=455, collect_list(Product_ID)=[73569, 3196]),
#  Row(User_ID=456, collect_list(Product_ID)=[23273, 3654, 38653, 12901, 102, 204825, 103, 2780, 33284, 12657, 73283, 39833, 36741]),
#  Row(User_ID=457, collect_list(Product_ID)=[4574, 6837]),
#  Row(User_ID=458, collect_list(Product_ID)=[585, 263]),
#  Row(User_ID=459, collect_list(Product_ID)=[2092, 105594]),
#  Row(User_ID=460, collect_list(Product_ID)=[7025]),
#  Row(User_ID=461, collect_list(Product_ID)=[18, 76]),
#  Row(User_ID=462, collect_list(Product_ID)=[52, 32184]),
#  Row(User_ID=463, collect_list(Product_ID)=[3227, 1836]),
#  Row(User_ID=464, collect_list(Product_ID)=[141954, 1428]),
#  Row(User_ID=465, collect_list(Product_ID)=[13652, 13277, 38246, 780, 21518, 7392, 1419]),
#  Row(User_ID=466, collect_list(Product_ID)=[368, 127953]),
#  Row(User_ID=467, collect_list(Product_ID)=[55784, 18283, 61531, 3243, 940, 661]),
#  Row(User_ID=468, collect_list(Product_ID)=[2413, 11462, 6788, 3545]),
#  Row(User_ID=469, collect_list(Product_ID)=[187]),
#  Row(User_ID=470, collect_list(Product_ID)=[116260]),
#  Row(User_ID=471, collect_list(Product_ID)=[202, 6105, 9, 29180, 39184, 6600, 2993, 140, 162, 2241]),
#  Row(User_ID=472, collect_list(Product_ID)=[2495, 3667, 23964]),
#  Row(User_ID=473, collect_list(Product_ID)=[179, 5225, 82, 16900]),
#  Row(User_ID=474, collect_list(Product_ID)=[65833, 28897, 25463]),
#  Row(User_ID=475, collect_list(Product_ID)=[13877, 25938]),
#  Row(User_ID=476, collect_list(Product_ID)=[95827, 77021]),
#  Row(User_ID=477, collect_list(Product_ID)=[111627, 2940]),
#  Row(User_ID=478, collect_list(Product_ID)=[162108]),
#  Row(User_ID=479, collect_list(Product_ID)=[9, 79644, 48086, 33687, 31796, 229, 110]),
#  Row(User_ID=480, collect_list(Product_ID)=[2574, 846, 12723, 6474]),
#  Row(User_ID=482, collect_list(Product_ID)=[5572, 154]),
#  Row(User_ID=483, collect_list(Product_ID)=[65900, 359, 34317]),
#  Row(User_ID=484, collect_list(Product_ID)=[47419]),
#  Row(User_ID=485, collect_list(Product_ID)=[4227]),
#  Row(User_ID=486, collect_list(Product_ID)=[303, 80988, 792]),
#  Row(User_ID=487, collect_list(Product_ID)=[978, 3743]),
#  Row(User_ID=488, collect_list(Product_ID)=[2092]),
#  Row(User_ID=489, collect_list(Product_ID)=[7054]),
#  Row(User_ID=490, collect_list(Product_ID)=[2052]),
#  Row(User_ID=491, collect_list(Product_ID)=[33034, 594]),
#  Row(User_ID=492, collect_list(Product_ID)=[43242, 181603]),
#  Row(User_ID=493, collect_list(Product_ID)=[12330, 3403, 18364, 2466, 92415]),
#  Row(User_ID=494, collect_list(Product_ID)=[6988, 1155, 19828, 9094, 4914]),
#  Row(User_ID=495, collect_list(Product_ID)=[13, 37592, 2348]),
#  Row(User_ID=496, collect_list(Product_ID)=[21516, 6709, 30074, 7246, 50]),
#  Row(User_ID=497, collect_list(Product_ID)=[1548, 28]),
#  Row(User_ID=498, collect_list(Product_ID)=[437, 41896]),
#  Row(User_ID=499, collect_list(Product_ID)=[15413]),
#  Row(User_ID=500, collect_list(Product_ID)=[709, 5636]),
#  Row(User_ID=501, collect_list(Product_ID)=[340, 24807, 6189, 1343]),
#  Row(User_ID=502, collect_list(Product_ID)=[1417, 203379]),
#  Row(User_ID=503, collect_list(Product_ID)=[488, 1858]),
#  Row(User_ID=504, collect_list(Product_ID)=[36818, 8612, 12209, 2607, 1535]),
#  Row(User_ID=505, collect_list(Product_ID)=[119790, 150536]),
#  Row(User_ID=506, collect_list(Product_ID)=[420, 6896, 7906, 590, 918, 12860, 620, 3, 99, 2, 34778, 161]),
#  Row(User_ID=507, collect_list(Product_ID)=[1564, 149473, 34198, 20142, 5535]),
#  Row(User_ID=508, collect_list(Product_ID)=[20556, 12347]),
#  Row(User_ID=509, collect_list(Product_ID)=[257]),
#  Row(User_ID=510, collect_list(Product_ID)=[5226, 80276]),
#  Row(User_ID=511, collect_list(Product_ID)=[59918, 36285, 128707, 4316, 2066, 300, 127, 5326, 5045, 50325, 125188]),
#  Row(User_ID=512, collect_list(Product_ID)=[10796]),
#  Row(User_ID=513, collect_list(Product_ID)=[2555, 717]),
#  Row(User_ID=514, collect_list(Product_ID)=[26614, 9399, 20345, 12764, 279, 3536, 6178, 2335, 36171, 238, 88872, 20566, 28457]),
#  Row(User_ID=516, collect_list(Product_ID)=[103, 241]),
#  Row(User_ID=518, collect_list(Product_ID)=[320]),
#  Row(User_ID=519, collect_list(Product_ID)=[27085, 5518]),
#  Row(User_ID=520, collect_list(Product_ID)=[68818, 1493, 9462, 703, 16632]),
#  Row(User_ID=521, collect_list(Product_ID)=[1862, 17891, 100485, 20084, 37992, 209, 1190, 0, 7831, 2399, 36635, 5992, 62149]),
#  Row(User_ID=522, collect_list(Product_ID)=[3998, 6, 249]),
#  Row(User_ID=523, collect_list(Product_ID)=[173233, 753, 9561, 17834, 197, 146947, 7210]),
#  Row(User_ID=524, collect_list(Product_ID)=[5875, 676]),
#  Row(User_ID=525, collect_list(Product_ID)=[413, 2178, 4147, 401, 1367]),
#  Row(User_ID=526, collect_list(Product_ID)=[14052, 12463, 114012, 274]),
#  Row(User_ID=527, collect_list(Product_ID)=[1500, 17970]),
#  Row(User_ID=528, collect_list(Product_ID)=[11206, 9062, 122]),
#  Row(User_ID=529, collect_list(Product_ID)=[854, 17785]),
#  Row(User_ID=530, collect_list(Product_ID)=[988, 42979, 991, 27312, 2890, 2650, 130, 132, 1805, 1498, 10173, 16762, 2665, 1561, 1977, 167467]),
#  Row(User_ID=531, collect_list(Product_ID)=[9051]),
#  Row(User_ID=532, collect_list(Product_ID)=[333, 712, 7795, 169923, 37077, 3094, 623, 23253]),
#  Row(User_ID=533, collect_list(Product_ID)=[18118, 32004, 48390, 61542]),
#  Row(User_ID=534, collect_list(Product_ID)=[17054, 854, 18660]),
#  Row(User_ID=535, collect_list(Product_ID)=[501, 11405, 1511, 172843]),
#  Row(User_ID=536, collect_list(Product_ID)=[10, 203]),
#  Row(User_ID=537, collect_list(Product_ID)=[844]),
#  Row(User_ID=538, collect_list(Product_ID)=[129]),
#  Row(User_ID=539, collect_list(Product_ID)=[22, 90053, 165943, 17018]),
#  Row(User_ID=540, collect_list(Product_ID)=[10425]),
#  Row(User_ID=541, collect_list(Product_ID)=[13600]),
#  Row(User_ID=542, collect_list(Product_ID)=[16466, 1134]),
#  Row(User_ID=543, collect_list(Product_ID)=[4707, 5124, 1972, 23402, 23017]),
#  Row(User_ID=544, collect_list(Product_ID)=[128673, 65217, 91261, 48294, 53024]),
#  Row(User_ID=545, collect_list(Product_ID)=[683, 12910, 55622]),
#  Row(User_ID=546, collect_list(Product_ID)=[9858, 3183, 10799, 51135, 68126]),
#  Row(User_ID=547, collect_list(Product_ID)=[116181, 5424, 1679, 6078]),
#  Row(User_ID=548, collect_list(Product_ID)=[164795]),
#  Row(User_ID=549, collect_list(Product_ID)=[27199, 29922, 129072, 7739, 33931]),
#  Row(User_ID=550, collect_list(Product_ID)=[51022, 12395, 46461, 7996, 532, 14448, 14822, 3024, 1427]),
#  Row(User_ID=551, collect_list(Product_ID)=[632, 9580, 406]),
#  Row(User_ID=552, collect_list(Product_ID)=[115374]),
#  Row(User_ID=553, collect_list(Product_ID)=[13914, 19558, 4824, 52214, 1423]),
#  Row(User_ID=554, collect_list(Product_ID)=[4028, 353]),
#  Row(User_ID=555, collect_list(Product_ID)=[206569, 7567, 3438, 191194]),
#  Row(User_ID=556, collect_list(Product_ID)=[46654, 33213, 19611, 21694, 2730, 41846]),
#  Row(User_ID=557, collect_list(Product_ID)=[70602, 56911, 1250, 7640]),
#  Row(User_ID=558, collect_list(Product_ID)=[141469, 4820, 788, 5567]),
#  Row(User_ID=559, collect_list(Product_ID)=[3355]),
#  Row(User_ID=560, collect_list(Product_ID)=[4194, 15208]),
#  Row(User_ID=561, collect_list(Product_ID)=[2120, 1769, 2110]),
#  Row(User_ID=562, collect_list(Product_ID)=[899]),
#  Row(User_ID=563, collect_list(Product_ID)=[940, 42902, 1078, 4242]),
#  Row(User_ID=564, collect_list(Product_ID)=[166919, 24516, 166429, 10821]),
#  Row(User_ID=565, collect_list(Product_ID)=[1684, 2872]),
#  Row(User_ID=566, collect_list(Product_ID)=[158297, 963]),
#  Row(User_ID=567, collect_list(Product_ID)=[943, 273]),
#  Row(User_ID=568, collect_list(Product_ID)=[59959]),
#  Row(User_ID=569, collect_list(Product_ID)=[1845, 10502]),
#  Row(User_ID=570, collect_list(Product_ID)=[23292, 17930, 22942]),
#  Row(User_ID=571, collect_list(Product_ID)=[1, 119821]),
#  Row(User_ID=572, collect_list(Product_ID)=[196, 459, 60170]),
#  Row(User_ID=573, collect_list(Product_ID)=[12841, 91927]),
#  Row(User_ID=574, collect_list(Product_ID)=[6960, 118181]),
#  Row(User_ID=575, collect_list(Product_ID)=[29672, 3746]),
#  Row(User_ID=576, collect_list(Product_ID)=[94006, 134, 81639, 22, 94450, 56644, 51293, 36365, 13547]),
#  Row(User_ID=577, collect_list(Product_ID)=[25592, 16950, 7979]),
#  Row(User_ID=578, collect_list(Product_ID)=[14]),
#  Row(User_ID=579, collect_list(Product_ID)=[319, 15979]),
#  Row(User_ID=580, collect_list(Product_ID)=[346, 150722]),
#  Row(User_ID=581, collect_list(Product_ID)=[68653, 1884, 34499]),
#  Row(User_ID=582, collect_list(Product_ID)=[75479, 170, 132, 140, 59274, 5303]),
#  Row(User_ID=583, collect_list(Product_ID)=[2049, 24937]),
#  Row(User_ID=584, collect_list(Product_ID)=[1422, 1321, 19144, 2832, 115549, 377]),
#  Row(User_ID=585, collect_list(Product_ID)=[18429, 1485, 234, 5644, 3175]),
#  Row(User_ID=586, collect_list(Product_ID)=[76382, 571]),
#  Row(User_ID=587, collect_list(Product_ID)=[854, 11580]),
#  Row(User_ID=588, collect_list(Product_ID)=[5441]),
#  Row(User_ID=589, collect_list(Product_ID)=[406]),
#  Row(User_ID=591, collect_list(Product_ID)=[1692, 37699]),
#  Row(User_ID=592, collect_list(Product_ID)=[33541, 32294]),
#  Row(User_ID=593, collect_list(Product_ID)=[34228, 1566, 99681, 159769, 68636, 100, 10812, 354]),
#  Row(User_ID=594, collect_list(Product_ID)=[85351]),
#  Row(User_ID=595, collect_list(Product_ID)=[664, 6257, 19380, 1531, 5157, 136348, 1278, 133000, 766, 17623, 2175, 14858, 20391, 51959, 27139, 27799, 8442, 81273, 24476, 305, 17557, 36191]),
#  Row(User_ID=596, collect_list(Product_ID)=[151366, 180190]),
#  Row(User_ID=597, collect_list(Product_ID)=[38685]),
#  Row(User_ID=598, collect_list(Product_ID)=[72896, 41, 48296]),
#  Row(User_ID=600, collect_list(Product_ID)=[17555]),
#  Row(User_ID=601, collect_list(Product_ID)=[194894, 15677, 17, 583, 1757]),
#  Row(User_ID=603, collect_list(Product_ID)=[1752]),
#  Row(User_ID=604, collect_list(Product_ID)=[111488, 6132, 8972]),
#  Row(User_ID=605, collect_list(Product_ID)=[14986, 84937, 3786, 87653]),
#  Row(User_ID=606, collect_list(Product_ID)=[4995, 55918, 2134]),
#  Row(User_ID=607, collect_list(Product_ID)=[16542, 733, 16861]),
#  Row(User_ID=609, collect_list(Product_ID)=[13078, 2748, 1964, 421, 131]),
#  Row(User_ID=610, collect_list(Product_ID)=[6286, 6, 12573, 81347]),
#  Row(User_ID=611, collect_list(Product_ID)=[17335, 19615, 11830]),
#  Row(User_ID=612, collect_list(Product_ID)=[1104, 46785, 13589, 12243]),
#  Row(User_ID=613, collect_list(Product_ID)=[57589, 142358, 30968]),
#  Row(User_ID=614, collect_list(Product_ID)=[15690, 7984]),
#  Row(User_ID=615, collect_list(Product_ID)=[5244]),
#  Row(User_ID=616, collect_list(Product_ID)=[1019, 115, 96]),
#  Row(User_ID=617, collect_list(Product_ID)=[20966]),
#  Row(User_ID=618, collect_list(Product_ID)=[158]),
#  Row(User_ID=619, collect_list(Product_ID)=[112490, 184577]),
#  Row(User_ID=620, collect_list(Product_ID)=[7552, 853]),
#  Row(User_ID=621, collect_list(Product_ID)=[13335, 67802, 27085]),
#  Row(User_ID=622, collect_list(Product_ID)=[4249, 483, 38802]),
#  Row(User_ID=623, collect_list(Product_ID)=[17938, 14829, 67833, 15590]),
#  Row(User_ID=624, collect_list(Product_ID)=[24332]),
#  Row(User_ID=625, collect_list(Product_ID)=[22583]),
#  Row(User_ID=626, collect_list(Product_ID)=[3117, 2234]),
#  Row(User_ID=627, collect_list(Product_ID)=[6892, 66365, 352]),
#  Row(User_ID=628, collect_list(Product_ID)=[6, 1139, 4]),
#  Row(User_ID=629, collect_list(Product_ID)=[20132, 21739]),
#  Row(User_ID=630, collect_list(Product_ID)=[137250, 8909, 19565]),
#  Row(User_ID=631, collect_list(Product_ID)=[7107, 111725]),
#  Row(User_ID=632, collect_list(Product_ID)=[989, 74079, 46, 355, 50587, 138, 12234, 8446, 84503]),
#  Row(User_ID=633, collect_list(Product_ID)=[146676]),
#  Row(User_ID=634, collect_list(Product_ID)=[1428, 117976, 15196, 1295]),
#  Row(User_ID=635, collect_list(Product_ID)=[37275, 8029, 5622, 1042, 41639, 33039, 4431, 5780, 910, 1214]),
#  Row(User_ID=636, collect_list(Product_ID)=[39925, 12378, 2756]),
#  Row(User_ID=637, collect_list(Product_ID)=[705, 102705]),
#  Row(User_ID=638, collect_list(Product_ID)=[4493, 612, 68]),
#  Row(User_ID=639, collect_list(Product_ID)=[7884, 26296]),
#  Row(User_ID=640, collect_list(Product_ID)=[12035]),
#  Row(User_ID=641, collect_list(Product_ID)=[149181, 11627]),
#  Row(User_ID=642, collect_list(Product_ID)=[821, 3067, 10122]),
#  Row(User_ID=643, collect_list(Product_ID)=[140421, 12595]),
#  Row(User_ID=644, collect_list(Product_ID)=[176328, 6736]),
#  Row(User_ID=645, collect_list(Product_ID)=[19461, 102, 5120, 81430]),
#  Row(User_ID=646, collect_list(Product_ID)=[270, 821, 2270, 8521, 81]),
#  Row(User_ID=647, collect_list(Product_ID)=[183478, 12916, 1492, 9621, 1695, 15518, 70632, 3121, 4549, 72318, 32, 19922, 2502, 23093, 11280, 124040, 3757, 6986, 33131, 468, 87687, 19187]),
#  Row(User_ID=648, collect_list(Product_ID)=[9363]),
#  Row(User_ID=649, collect_list(Product_ID)=[1472, 1]),
#  Row(User_ID=650, collect_list(Product_ID)=[301, 1375, 156, 403]),
#  Row(User_ID=651, collect_list(Product_ID)=[35, 6221, 23, 25620, 0, 122, 38867, 567, 1711, 19337, 2792, 135, 84]),
#  Row(User_ID=652, collect_list(Product_ID)=[15533, 10044, 132820, 13261, 34127]),
#  Row(User_ID=653, collect_list(Product_ID)=[6182, 27393]),
#  Row(User_ID=654, collect_list(Product_ID)=[100473, 35902, 153283, 131824, 12819]),
#  Row(User_ID=655, collect_list(Product_ID)=[65253, 36]),
#  Row(User_ID=656, collect_list(Product_ID)=[34494, 162632]),
#  Row(User_ID=657, collect_list(Product_ID)=[157, 99]),
#  Row(User_ID=658, collect_list(Product_ID)=[29916]),
#  Row(User_ID=659, collect_list(Product_ID)=[83480, 6694]),
#  Row(User_ID=660, collect_list(Product_ID)=[55240]),
#  Row(User_ID=661, collect_list(Product_ID)=[33299, 44, 3499, 81163, 121, 33116, 1179, 40734, 1055, 415]),
#  Row(User_ID=662, collect_list(Product_ID)=[2452, 5937, 5157]),
#  Row(User_ID=664, collect_list(Product_ID)=[13662, 79259]),
#  Row(User_ID=665, collect_list(Product_ID)=[30895, 134, 21166, 86306, 46082, 50436, 78666, 16636, 27313, 19443, 2345, 9400, 6154, 9549, 3338, 4586]),
#  Row(User_ID=666, collect_list(Product_ID)=[6867, 17085]),
#  Row(User_ID=667, collect_list(Product_ID)=[8740, 22043, 25783, 141421, 53217, 49024, 150795, 1697, 11236, 22159]),
#  Row(User_ID=668, collect_list(Product_ID)=[19573, 459, 136475, 31634, 56908, 3831, 3217, 28170, 15332, 116363]),
#  Row(User_ID=669, collect_list(Product_ID)=[8097, 608, 1323, 30]),
#  Row(User_ID=670, collect_list(Product_ID)=[2465, 558]),
#  Row(User_ID=671, collect_list(Product_ID)=[157945, 1469, 9486, 31845]),
#  Row(User_ID=672, collect_list(Product_ID)=[2285]),
#  Row(User_ID=673, collect_list(Product_ID)=[121628]),
#  Row(User_ID=674, collect_list(Product_ID)=[1462, 26450, 17950]),
#  Row(User_ID=675, collect_list(Product_ID)=[125396, 23, 13325]),
#  Row(User_ID=676, collect_list(Product_ID)=[5632, 194235, 742, 1290, 14389, 17, 788, 5550, 238, 1675, 330, 6833, 8263, 1740, 135, 1162, 785]),
#  Row(User_ID=677, collect_list(Product_ID)=[17973, 285, 114, 443, 18423, 5687]),
#  Row(User_ID=678, collect_list(Product_ID)=[4114, 4544]),
#  Row(User_ID=679, collect_list(Product_ID)=[13629, 10614]),
#  Row(User_ID=680, collect_list(Product_ID)=[3452, 166316, 6520]),
#  Row(User_ID=681, collect_list(Product_ID)=[1073, 11457]),
#  Row(User_ID=682, collect_list(Product_ID)=[38910, 291]),
#  Row(User_ID=683, collect_list(Product_ID)=[2703]),
#  Row(User_ID=684, collect_list(Product_ID)=[1052, 54660]),
#  Row(User_ID=685, collect_list(Product_ID)=[9460]),
#  Row(User_ID=686, collect_list(Product_ID)=[15452, 90, 15657]),
#  Row(User_ID=687, collect_list(Product_ID)=[595, 17880, 93902, 10162, 69622, 35946, 136337, 103933]),
#  Row(User_ID=688, collect_list(Product_ID)=[887, 4420, 73035, 18227, 1578, 7447, 2505]),
#  Row(User_ID=689, collect_list(Product_ID)=[27702, 2418]),
#  Row(User_ID=690, collect_list(Product_ID)=[9730, 7291, 9332, 3286]),
#  Row(User_ID=691, collect_list(Product_ID)=[4481, 13209, 154, 24658, 13501]),
#  Row(User_ID=692, collect_list(Product_ID)=[371]),
#  Row(User_ID=693, collect_list(Product_ID)=[70, 21658, 46144, 126571, 1755]),
#  Row(User_ID=694, collect_list(Product_ID)=[231, 168252]),
#  Row(User_ID=695, collect_list(Product_ID)=[1163, 2225, 624]),
#  Row(User_ID=696, collect_list(Product_ID)=[606, 1765, 19742, 6520, 52949, 136572, 18257, 529, 13639, 91]),
#  Row(User_ID=697, collect_list(Product_ID)=[205, 2948]),
#  Row(User_ID=698, collect_list(Product_ID)=[6239, 35499, 365]),
#  Row(User_ID=699, collect_list(Product_ID)=[35557]),
#  Row(User_ID=700, collect_list(Product_ID)=[7129, 712, 33183, 1041]),
#  Row(User_ID=701, collect_list(Product_ID)=[310, 18482]),
#  Row(User_ID=702, collect_list(Product_ID)=[12479, 37, 2773]),
#  Row(User_ID=703, collect_list(Product_ID)=[67082, 5140, 89886]),
#  Row(User_ID=704, collect_list(Product_ID)=[11594]),
#  Row(User_ID=705, collect_list(Product_ID)=[2157]),
#  Row(User_ID=706, collect_list(Product_ID)=[112404]),
#  Row(User_ID=707, collect_list(Product_ID)=[2829]),
#  Row(User_ID=708, collect_list(Product_ID)=[49109, 31359, 1036, 787, 219]),
#  Row(User_ID=709, collect_list(Product_ID)=[1127]),
#  Row(User_ID=711, collect_list(Product_ID)=[109483, 20814]),
#  Row(User_ID=712, collect_list(Product_ID)=[6933, 7119, 25, 609, 81045, 115966, 13951]),
#  Row(User_ID=713, collect_list(Product_ID)=[5510, 4957]),
#  Row(User_ID=714, collect_list(Product_ID)=[17610, 9880]),
#  Row(User_ID=715, collect_list(Product_ID)=[2954, 35505, 69448]),
#  Row(User_ID=716, collect_list(Product_ID)=[15401, 9257, 10015, 175145]),
#  Row(User_ID=717, collect_list(Product_ID)=[15946, 106416, 1221, 137]),
#  Row(User_ID=718, collect_list(Product_ID)=[19569, 165558, 17071]),
#  Row(User_ID=719, collect_list(Product_ID)=[37239, 559, 12975]),
#  Row(User_ID=720, collect_list(Product_ID)=[50956]),
#  Row(User_ID=721, collect_list(Product_ID)=[2615, 1221]),
#  Row(User_ID=722, collect_list(Product_ID)=[3248]),
#  Row(User_ID=723, collect_list(Product_ID)=[160458, 11074, 6030]),
#  Row(User_ID=724, collect_list(Product_ID)=[39550, 59659, 9393, 71478]),
#  Row(User_ID=726, collect_list(Product_ID)=[78020, 14, 64687, 12638, 365, 15329]),
#  Row(User_ID=727, collect_list(Product_ID)=[2947, 3217, 30165, 1295, 537]),
#  Row(User_ID=728, collect_list(Product_ID)=[3777]),
#  Row(User_ID=729, collect_list(Product_ID)=[1050]),
#  Row(User_ID=730, collect_list(Product_ID)=[19117, 5170, 424, 165832, 10200]),
#  Row(User_ID=731, collect_list(Product_ID)=[6184, 100722, 163267, 108435]),
#  Row(User_ID=732, collect_list(Product_ID)=[9510, 172, 3]),
#  Row(User_ID=733, collect_list(Product_ID)=[14817, 9343, 12293]),
#  Row(User_ID=734, collect_list(Product_ID)=[683, 1954, 37679, 1052, 1345, 3403, 8653, 4178, 255, 30819, 12024, 208333, 3258, 884, 6521]),
# ...
#  Row(User_ID=781, collect_list(Product_ID)=[1552, 2695]),
#  Row(User_ID=782, collect_list(Product_ID)=[3293]),
#  Row(User_ID=783, collect_list(Product_ID)=[371, 3101, 1006, 6076, 728, 195]),
#  Row(User_ID=784, collect_list(Product_ID)=[985]),
#  Row(User_ID=786, collect_list(Product_ID)=[144, 105179]),
#  Row(User_ID=787, collect_list(Product_ID)=[63536, 27998]),
#  Row(User_ID=788, collect_list(Product_ID)=[2891, 670, 13361, 73913, 7617, 976, 12569]),
#  Row(User_ID=789, collect_list(Product_ID)=[102368, 59329, 20614]),
#  Row(User_ID=790, collect_list(Product_ID)=[10246, 2430, 479]),
#  Row(User_ID=791, collect_list(Product_ID)=[15190, 32]),
#  Row(User_ID=792, collect_list(Product_ID)=[2450, 2366, 92, 5196, 10385, 11984]),
#  Row(User_ID=793, collect_list(Product_ID)=[1376, 1192, 88675]),
#  Row(User_ID=794, collect_list(Product_ID)=[16589]),
#  Row(User_ID=795, collect_list(Product_ID)=[15443, 1923]),
#  Row(User_ID=796, collect_list(Product_ID)=[8995, 530, 6021, 125, 24908, 23, 1551, 126, 14079, 21373]),
#  Row(User_ID=797, collect_list(Product_ID)=[3062]),
#  Row(User_ID=798, collect_list(Product_ID)=[26742, 2199, 191205, 4754]),
#  Row(User_ID=799, collect_list(Product_ID)=[64079, 9103, 17952, 106845, 15448, 12204, 22037, 6680, 220, 9992, 42345, 64646, 904]),
#  Row(User_ID=800, collect_list(Product_ID)=[596]),
#  Row(User_ID=801, collect_list(Product_ID)=[13, 79413]),
#  Row(User_ID=802, collect_list(Product_ID)=[7097, 90412, 32079]),
#  Row(User_ID=803, collect_list(Product_ID)=[5672]),
#  Row(User_ID=804, collect_list(Product_ID)=[27274, 14, 24917]),
#  Row(User_ID=805, collect_list(Product_ID)=[505, 35370]),
#  Row(User_ID=806, collect_list(Product_ID)=[143690, 28318, 9276, 226]),
#  Row(User_ID=807, collect_list(Product_ID)=[581, 80]),
#  Row(User_ID=808, collect_list(Product_ID)=[14532, 3608, 692, 14832]),
#  Row(User_ID=809, collect_list(Product_ID)=[8096]),
#  Row(User_ID=810, collect_list(Product_ID)=[64232, 49131, 1918, 28253, 820]),
#  Row(User_ID=811, collect_list(Product_ID)=[74273, 131449]),
#  Row(User_ID=812, collect_list(Product_ID)=[1125, 11937]),
#  Row(User_ID=813, collect_list(Product_ID)=[26, 61, 34, 1195]),
#  Row(User_ID=814, collect_list(Product_ID)=[12890, 20696, 172483, 7880]),
#  Row(User_ID=815, collect_list(Product_ID)=[15035, 35353, 101382]),
#  Row(User_ID=816, collect_list(Product_ID)=[3993, 7144]),
#  Row(User_ID=817, collect_list(Product_ID)=[271, 284]),
#  Row(User_ID=818, collect_list(Product_ID)=[14]),
#  Row(User_ID=819, collect_list(Product_ID)=[151673, 16984, 30544, 7522]),
#  Row(User_ID=820, collect_list(Product_ID)=[288]),
#  Row(User_ID=822, collect_list(Product_ID)=[541, 71613, 131]),
#  Row(User_ID=823, collect_list(Product_ID)=[301, 805, 4]),
#  Row(User_ID=824, collect_list(Product_ID)=[45644, 3022]),
#  Row(User_ID=825, collect_list(Product_ID)=[2450, 19898, 4479]),
#  Row(User_ID=826, collect_list(Product_ID)=[2273, 56971, 4784]),
#  Row(User_ID=827, collect_list(Product_ID)=[45241, 141]),
#  Row(User_ID=828, collect_list(Product_ID)=[1540, 7232, 855]),
#  Row(User_ID=829, collect_list(Product_ID)=[42044, 66590, 83705]),
#  Row(User_ID=830, collect_list(Product_ID)=[16370, 202701, 72, 241]),
#  Row(User_ID=831, collect_list(Product_ID)=[15760]),
#  Row(User_ID=832, collect_list(Product_ID)=[2390, 1145, 1647, 3143]),
#  Row(User_ID=833, collect_list(Product_ID)=[4646, 95387]),
#  Row(User_ID=834, collect_list(Product_ID)=[11559]),
#  Row(User_ID=835, collect_list(Product_ID)=[155838, 17, 1899, 154, 78938]),
#  Row(User_ID=836, collect_list(Product_ID)=[85684, 11301, 855]),
#  Row(User_ID=837, collect_list(Product_ID)=[11456, 125580, 76025, 70966, 167056]),
#  Row(User_ID=838, collect_list(Product_ID)=[119281]),
#  Row(User_ID=839, collect_list(Product_ID)=[16036]),
#  Row(User_ID=840, collect_list(Product_ID)=[3622]),
#  Row(User_ID=842, collect_list(Product_ID)=[58680]),
#  Row(User_ID=843, collect_list(Product_ID)=[125, 11213, 59286]),
#  Row(User_ID=844, collect_list(Product_ID)=[242, 6670, 6328, 371, 2692, 119492, 55469, 1992]),
#  Row(User_ID=845, collect_list(Product_ID)=[10335, 3088, 3338]),
#  Row(User_ID=846, collect_list(Product_ID)=[17518, 3195]),
#  Row(User_ID=847, collect_list(Product_ID)=[151, 331, 137]),
#  Row(User_ID=848, collect_list(Product_ID)=[30810, 10580]),
#  Row(User_ID=849, collect_list(Product_ID)=[53654, 53911, 4270]),
#  Row(User_ID=850, collect_list(Product_ID)=[379, 12629, 982, 14554, 2384, 1645, 16225, 34, 17010, 10313, 2848, 5908, 189366, 873, 20308, 22399, 2056, 35820, 42588, 20268]),
#  Row(User_ID=851, collect_list(Product_ID)=[144931, 1444]),
#  Row(User_ID=852, collect_list(Product_ID)=[23407, 40407]),
#  Row(User_ID=853, collect_list(Product_ID)=[1038, 10147, 1229, 24390, 996]),
#  Row(User_ID=854, collect_list(Product_ID)=[67323]),
#  Row(User_ID=855, collect_list(Product_ID)=[16178]),
#  Row(User_ID=856, collect_list(Product_ID)=[25233, 6557, 9804]),
#  Row(User_ID=857, collect_list(Product_ID)=[4263, 28372, 2, 4094]),
#  Row(User_ID=858, collect_list(Product_ID)=[4003, 3741, 42785]),
#  Row(User_ID=859, collect_list(Product_ID)=[115, 1320, 41720]),
#  Row(User_ID=860, collect_list(Product_ID)=[2069, 21]),
#  Row(User_ID=862, collect_list(Product_ID)=[62593, 1527, 13053]),
#  Row(User_ID=863, collect_list(Product_ID)=[33497]),
#  Row(User_ID=864, collect_list(Product_ID)=[17932, 21161, 94447]),
#  Row(User_ID=865, collect_list(Product_ID)=[6811]),
#  Row(User_ID=866, collect_list(Product_ID)=[29454, 1158, 907]),
#  Row(User_ID=867, collect_list(Product_ID)=[780]),
#  Row(User_ID=868, collect_list(Product_ID)=[875]),
#  Row(User_ID=869, collect_list(Product_ID)=[39314]),
#  Row(User_ID=870, collect_list(Product_ID)=[157839, 29246]),
#  Row(User_ID=871, collect_list(Product_ID)=[25720, 766]),
#  Row(User_ID=872, collect_list(Product_ID)=[99712, 57185, 3358]),
#  Row(User_ID=873, collect_list(Product_ID)=[457]),
#  Row(User_ID=874, collect_list(Product_ID)=[1596, 3024]),
#  Row(User_ID=875, collect_list(Product_ID)=[108, 8940, 1633]),
#  Row(User_ID=876, collect_list(Product_ID)=[2184, 11660]),
#  Row(User_ID=877, collect_list(Product_ID)=[29523, 1720, 108877, 18217, 43016, 4054, 5657]),
#  Row(User_ID=878, collect_list(Product_ID)=[68282]),
#  Row(User_ID=879, collect_list(Product_ID)=[17188]),
#  Row(User_ID=880, collect_list(Product_ID)=[2862, 44711, 5039]),
#  Row(User_ID=881, collect_list(Product_ID)=[380]),
#  Row(User_ID=883, collect_list(Product_ID)=[483, 1341, 1268]),
#  Row(User_ID=884, collect_list(Product_ID)=[2478, 18505, 911, 45715, 58238, 99999]),
#  Row(User_ID=885, collect_list(Product_ID)=[118425, 11848]),
#  Row(User_ID=886, collect_list(Product_ID)=[174]),
#  Row(User_ID=887, collect_list(Product_ID)=[5677, 9253]),
#  Row(User_ID=888, collect_list(Product_ID)=[12303, 10409, 70932]),
#  Row(User_ID=889, collect_list(Product_ID)=[445, 36456, 2040, 4, 1262]),
#  Row(User_ID=890, collect_list(Product_ID)=[23616, 5194]),
#  Row(User_ID=891, collect_list(Product_ID)=[10880, 27579]),
#  Row(User_ID=892, collect_list(Product_ID)=[11260, 238, 91767]),
#  Row(User_ID=893, collect_list(Product_ID)=[92194, 49904, 26207, 570, 2707, 14265]),
#  Row(User_ID=894, collect_list(Product_ID)=[1215, 6610, 59637, 25920, 28881, 8922, 3749, 37830, 7465, 92, 13439, 456, 9990, 2369]),
#  Row(User_ID=895, collect_list(Product_ID)=[83897]),
#  Row(User_ID=896, collect_list(Product_ID)=[132454]),
#  Row(User_ID=897, collect_list(Product_ID)=[836, 3668]),
#  Row(User_ID=898, collect_list(Product_ID)=[11759, 99273, 6969]),
#  Row(User_ID=899, collect_list(Product_ID)=[1414, 46970]),
#  Row(User_ID=900, collect_list(Product_ID)=[5172, 69, 76]),
#  Row(User_ID=901, collect_list(Product_ID)=[17482, 5066, 5204]),
#  Row(User_ID=902, collect_list(Product_ID)=[2052, 3288, 6436, 36405, 7264, 179532]),
#  Row(User_ID=903, collect_list(Product_ID)=[1235, 51413]),
#  Row(User_ID=904, collect_list(Product_ID)=[9539, 232, 863]),
#  Row(User_ID=905, collect_list(Product_ID)=[127820, 45051, 133836]),
#  Row(User_ID=906, collect_list(Product_ID)=[301, 71989]),
#  Row(User_ID=907, collect_list(Product_ID)=[912, 64, 84]),
#  Row(User_ID=908, collect_list(Product_ID)=[4844, 64240]),
#  Row(User_ID=909, collect_list(Product_ID)=[9836, 1782, 14746, 17051]),
#  Row(User_ID=910, collect_list(Product_ID)=[22187, 150573, 76143, 8212, 9495]),
#  Row(User_ID=911, collect_list(Product_ID)=[5114, 1311]),
#  Row(User_ID=912, collect_list(Product_ID)=[88354, 2603]),
#  Row(User_ID=913, collect_list(Product_ID)=[132508, 13587, 3478]),
#  Row(User_ID=914, collect_list(Product_ID)=[1745, 1130]),
#  Row(User_ID=915, collect_list(Product_ID)=[5860, 4071]),
#  Row(User_ID=916, collect_list(Product_ID)=[28903, 49, 12193, 20, 36938]),
#  Row(User_ID=917, collect_list(Product_ID)=[82348]),
#  Row(User_ID=918, collect_list(Product_ID)=[215]),
#  Row(User_ID=919, collect_list(Product_ID)=[14911, 3766]),
#  Row(User_ID=920, collect_list(Product_ID)=[2242, 152140, 16797, 163883]),
#  Row(User_ID=921, collect_list(Product_ID)=[21424, 181]),
#  Row(User_ID=922, collect_list(Product_ID)=[26642]),
#  Row(User_ID=923, collect_list(Product_ID)=[843, 110865]),
#  Row(User_ID=924, collect_list(Product_ID)=[2387, 13143, 12156]),
#  Row(User_ID=925, collect_list(Product_ID)=[2294, 1275]),
#  Row(User_ID=926, collect_list(Product_ID)=[43853, 32796, 10174, 15381, 9510]),
#  Row(User_ID=927, collect_list(Product_ID)=[944, 59, 8439]),
#  Row(User_ID=929, collect_list(Product_ID)=[128862, 4232, 38764, 233]),
#  Row(User_ID=930, collect_list(Product_ID)=[13742, 32492, 9981, 16044, 933, 39599, 162248, 0, 1312, 112, 66761, 9571]),
#  Row(User_ID=931, collect_list(Product_ID)=[1255, 14242, 853]),
#  Row(User_ID=932, collect_list(Product_ID)=[6948, 8021]),
#  Row(User_ID=933, collect_list(Product_ID)=[15249, 2203, 932]),
#  Row(User_ID=934, collect_list(Product_ID)=[8995, 566, 24306, 9868, 40]),
#  Row(User_ID=935, collect_list(Product_ID)=[658, 5459]),
#  Row(User_ID=936, collect_list(Product_ID)=[18696, 57722, 94737, 11425, 3019]),
#  Row(User_ID=937, collect_list(Product_ID)=[88286, 1246, 52840, 5662]),
#  Row(User_ID=938, collect_list(Product_ID)=[73, 526, 1788, 67, 18579, 97879, 174]),
#  Row(User_ID=939, collect_list(Product_ID)=[24431, 782, 13911]),
#  Row(User_ID=940, collect_list(Product_ID)=[4715]),
#  Row(User_ID=941, collect_list(Product_ID)=[11588, 10323, 33779]),
#  Row(User_ID=942, collect_list(Product_ID)=[62952, 461]),
#  Row(User_ID=943, collect_list(Product_ID)=[164, 2873, 17, 7422]),
#  Row(User_ID=944, collect_list(Product_ID)=[7070, 3597]),
#  Row(User_ID=945, collect_list(Product_ID)=[7771, 106484]),
#  Row(User_ID=946, collect_list(Product_ID)=[119238]),
#  Row(User_ID=947, collect_list(Product_ID)=[151322]),
#  Row(User_ID=948, collect_list(Product_ID)=[98, 5402]),
#  Row(User_ID=949, collect_list(Product_ID)=[103127]),
#  Row(User_ID=950, collect_list(Product_ID)=[4512, 24327]),
#  Row(User_ID=951, collect_list(Product_ID)=[11, 32262, 2228, 464, 766, 28326]),
#  Row(User_ID=953, collect_list(Product_ID)=[661]),
#  Row(User_ID=954, collect_list(Product_ID)=[124038, 3745, 13975, 36714]),
#  Row(User_ID=955, collect_list(Product_ID)=[92206, 5291, 24735, 2627, 1432]),
#  Row(User_ID=956, collect_list(Product_ID)=[11853, 1373]),
#  Row(User_ID=957, collect_list(Product_ID)=[18597]),
#  Row(User_ID=958, collect_list(Product_ID)=[127, 2178, 246]),
#  Row(User_ID=959, collect_list(Product_ID)=[13119, 84025, 2031]),
#  Row(User_ID=960, collect_list(Product_ID)=[15597, 45673]),
#  Row(User_ID=961, collect_list(Product_ID)=[555, 28127, 571]),
#  Row(User_ID=962, collect_list(Product_ID)=[14369, 2050]),
#  Row(User_ID=963, collect_list(Product_ID)=[148874, 9032, 2, 852]),
#  Row(User_ID=964, collect_list(Product_ID)=[1380, 12951, 13482]),
#  Row(User_ID=965, collect_list(Product_ID)=[114976]),
#  Row(User_ID=966, collect_list(Product_ID)=[16491]),
#  Row(User_ID=968, collect_list(Product_ID)=[108115, 35162, 29775, 5182, 53645, 17411]),
#  Row(User_ID=969, collect_list(Product_ID)=[6400]),
#  Row(User_ID=970, collect_list(Product_ID)=[16, 1125]),
#  Row(User_ID=972, collect_list(Product_ID)=[18686, 42675, 8, 13127]),
#  Row(User_ID=973, collect_list(Product_ID)=[496]),
#  Row(User_ID=974, collect_list(Product_ID)=[30655, 1515, 4802, 401, 4884, 42135, 41563, 3567, 14784]),
#  Row(User_ID=975, collect_list(Product_ID)=[45112, 31051, 25199]),
#  Row(User_ID=976, collect_list(Product_ID)=[14, 6808, 36682]),
#  Row(User_ID=977, collect_list(Product_ID)=[539]),
#  Row(User_ID=978, collect_list(Product_ID)=[62124]),
#  Row(User_ID=979, collect_list(Product_ID)=[374, 10834]),
#  Row(User_ID=980, collect_list(Product_ID)=[22114]),
#  Row(User_ID=981, collect_list(Product_ID)=[14, 216]),
#  Row(User_ID=982, collect_list(Product_ID)=[2684, 25486]),
#  Row(User_ID=983, collect_list(Product_ID)=[2334, 5213, 263]),
#  Row(User_ID=984, collect_list(Product_ID)=[16440, 3347, 22117, 2707]),
#  Row(User_ID=985, collect_list(Product_ID)=[1784, 124540, 3277, 81468]),
#  Row(User_ID=986, collect_list(Product_ID)=[76352, 68861]),
#  Row(User_ID=987, collect_list(Product_ID)=[7405, 163186]),
#  Row(User_ID=988, collect_list(Product_ID)=[9532, 10430, 21721, 18953, 1181, 6663]),
#  Row(User_ID=989, collect_list(Product_ID)=[1573, 1773, 14062, 39786]),
#  Row(User_ID=990, collect_list(Product_ID)=[24767, 42923]),
#  Row(User_ID=991, collect_list(Product_ID)=[410, 695, 4464]),
#  Row(User_ID=992, collect_list(Product_ID)=[6050, 7222, 317]),
#  Row(User_ID=993, collect_list(Product_ID)=[489, 24881, 1094, 36875]),
#  Row(User_ID=994, collect_list(Product_ID)=[74616, 9967, 10744, 97446]),
#  Row(User_ID=995, collect_list(Product_ID)=[31289, 1816, 134, 15957, 19267, 1071, 7980, 51941, 29, 12006, 80237, 2532, 1725, 12514, 16315]),
#  Row(User_ID=996, collect_list(Product_ID)=[22130]),
#  Row(User_ID=998, collect_list(Product_ID)=[2267, 1175, 1071, 1081, 174, 5663]),
#  Row(User_ID=999, collect_list(Product_ID)=[97222, 26738, 2938, 50449]),
#  Row(User_ID=1000, collect_list(Product_ID)=[55208, 1649]),
#  Row(User_ID=1001, collect_list(Product_ID)=[6691, 298]),
#  Row(User_ID=1002, collect_list(Product_ID)=[231]),
#  Row(User_ID=1003, collect_list(Product_ID)=[116797, 47176, 36385, 70934, 6319, 42310]),
#  Row(User_ID=1004, collect_list(Product_ID)=[1721, 5703, 29653]),
#  Row(User_ID=1005, collect_list(Product_ID)=[6930, 27801, 721]),
#  Row(User_ID=1006, collect_list(Product_ID)=[10830]),
#  Row(User_ID=1007, collect_list(Product_ID)=[431, 33197, 4847, 3146, 266, 30603]),
#  Row(User_ID=1008, collect_list(Product_ID)=[3030, 15540, 13930, 775, 197403, 1125]),
#  Row(User_ID=1009, collect_list(Product_ID)=[207925, 1035, 3625, 19577]),
#  Row(User_ID=1010, collect_list(Product_ID)=[13, 371, 7290]),
#  Row(User_ID=1011, collect_list(Product_ID)=[668, 1938]),
#  Row(User_ID=1012, collect_list(Product_ID)=[203455, 59965, 50923, 361, 92650]),
#  Row(User_ID=1013, collect_list(Product_ID)=[2389, 803, 1296, 2, 2193]),
#  Row(User_ID=1014, collect_list(Product_ID)=[7]),
#  Row(User_ID=1015, collect_list(Product_ID)=[23121, 17]),
#  Row(User_ID=1016, collect_list(Product_ID)=[46, 192657, 3071, 128149, 7051, 297]),
#  Row(User_ID=1017, collect_list(Product_ID)=[7307, 58087, 58633]),
#  Row(User_ID=1018, collect_list(Product_ID)=[24454, 11069, 49, 4126, 470, 16398]),
#  Row(User_ID=1020, collect_list(Product_ID)=[8438, 1062, 5530, 1343]),
#  Row(User_ID=1021, collect_list(Product_ID)=[251, 332, 67, 361, 3769]),
#  Row(User_ID=1022, collect_list(Product_ID)=[12608, 31578, 36699, 53628, 66804, 6172]),
#  Row(User_ID=1023, collect_list(Product_ID)=[29880]),
#  Row(User_ID=1026, collect_list(Product_ID)=[1264, 1362]),
#  Row(User_ID=1027, collect_list(Product_ID)=[15770, 16968]),
#  Row(User_ID=1029, collect_list(Product_ID)=[28096, 425, 135]),
#  Row(User_ID=1030, collect_list(Product_ID)=[1955]),
#  Row(User_ID=1031, collect_list(Product_ID)=[7949, 67341, 3782]),
#  Row(User_ID=1032, collect_list(Product_ID)=[5307, 1579, 586]),
#  Row(User_ID=1033, collect_list(Product_ID)=[170046]),
#  Row(User_ID=1034, collect_list(Product_ID)=[11849, 78889]),
#  Row(User_ID=1035, collect_list(Product_ID)=[6273, 1283]),
#  Row(User_ID=1036, collect_list(Product_ID)=[104004, 408]),
#  Row(User_ID=1037, collect_list(Product_ID)=[71376, 52578, 9198]),
#  Row(User_ID=1039, collect_list(Product_ID)=[7415]),
#  Row(User_ID=1040, collect_list(Product_ID)=[73778, 9017, 24200]),
#  ...]

# %% [markdown]
# Filter out the users in the test set but not in the train set

# %%
user_in_train=train_df.select('User_ID').distinct().cache()
item_in_train=train_df.select('Product_ID').distinct().cache()
filtered_test_df=test_df.join(user_in_train,(test_df.User_ID==user_in_train.User_ID)).select(test_df.User_ID,'Product_ID','rating')
filtered_test_df=filtered_test_df.join(item_in_train,(filtered_test_df.Product_ID==item_in_train.Product_ID)).select('User_ID',filtered_test_df.Product_ID).cache()
filtered_test_df.orderBy('User_ID').show()
# Out:
# +-------+----------+
# |User_ID|Product_ID|
# +-------+----------+
# |      1|     33783|
# |      1|     45751|
# |      1|      5416|
# |      1|      1857|
# |      2|      2047|
# |      5|       171|
# |      6|    102555|
# |      6|     12887|
# |      6|    104722|
# |      6|      7392|
# |      8|     44965|
# |      9|      2507|
# |     10|     46288|
# |     13|      6897|
# |     14|        14|
# |     14|      1544|
# |     14|       175|
# |     14|     85069|
# |     16|     21189|
# |     16|     10846|
# +-------+----------+
# only showing top 20 rows

# %%
test_groupby_item = filtered_test_df.groupBy("User_ID").agg(collect_list("Product_ID")).orderBy('User_ID').cache()
test_groupby_item.show()
# Out:
# +-------+------------------------+
# |User_ID|collect_list(Product_ID)|
# +-------+------------------------+
# |      1|    [5416, 45751, 185...|
# |      2|                  [2047]|
# |      5|                   [171]|
# |      6|    [7392, 102555, 10...|
# |      8|                 [44965]|
# |      9|                  [2507]|
# |     10|                 [46288]|
# |     13|                  [6897]|
# |     14|    [85069, 1544, 175...|
# |     16|    [6, 5, 21189, 10846]|
# |     17|    [18242, 945, 9748...|
# |     18|           [46685, 5094]|
# |     19|                  [6944]|
# |     20|           [1845, 68765]|
# |     21|                  [7735]|
# |     22|                  [4398]|
# |     25|                  [1162]|
# |     28|              [384, 519]|
# |     30|                [127532]|
# |     33|                  [1933]|
# +-------+------------------------+
# only showing top 20 rows

# %% [markdown]
# Function used to find 10 recommend products for each user

# %%
def recommend(*param):
    global popular_item_id
    user_item=[param[0][0]]
    value=[]
    count=0
    for i in range(20):
        if popular_item_id[i] not in param[0][1]:
            value.append(popular_item_id[i])
            count+=1
            if count==10:
                break
    user_item.append(value)
    return user_item

# %%
recommend_list=[]
for i in range(len(train_list)):
    recommend_list.append(recommend(train_list[i]))

# %% [markdown]
# Prediction of the recommendations for each user

# %%
train_recommend=sc.parallelize(recommend_list).toDF().select(col('_1').alias('User_ID'),col('_2').alias('Recommend_Item_train')).cache()
train_recommend.show(10)
# Out:
# +-------+--------------------+
# |User_ID|Recommend_Item_train|
# +-------+--------------------+
# |      0|[128593, 167071, ...|
# |      1|[128593, 167071, ...|
# |      2|[128593, 167071, ...|
# |      3|[128593, 167071, ...|
# |      5|[128593, 167071, ...|
# |      6|[128593, 167071, ...|
# |      7|[128593, 167071, ...|
# |      8|[128593, 167071, ...|
# |      9|[128593, 167071, ...|
# |     10|[128593, 167071, ...|
# +-------+--------------------+
# only showing top 10 rows

# %% [markdown]
# Truly purchase in the test set

# %%
test_recommend=test_groupby_item.select(col('User_ID'),col('collect_list(Product_ID)').alias('Recommend_Item_test')).cache()
test_recommend.show(10)
# Out:
# +-------+--------------------+
# |User_ID| Recommend_Item_test|
# +-------+--------------------+
# |      1|[5416, 45751, 185...|
# |      2|              [2047]|
# |      5|               [171]|
# |      6|[7392, 102555, 10...|
# |      8|             [44965]|
# |      9|              [2507]|
# |     10|             [46288]|
# |     13|              [6897]|
# |     14|[85069, 1544, 175...|
# |     16|[6, 5, 21189, 10846]|
# +-------+--------------------+
# only showing top 10 rows

# %%
final_test=test_recommend.join(train_recommend,(test_recommend.User_ID==train_recommend.User_ID)).select(test_recommend.User_ID,'Recommend_Item_test','Recommend_Item_train').orderBy('User_ID').cache()
final_test.show(10)
# Out:
# +-------+--------------------+--------------------+
# |User_ID| Recommend_Item_test|Recommend_Item_train|
# +-------+--------------------+--------------------+
# |      1|[5416, 45751, 185...|[128593, 167071, ...|
# |      2|              [2047]|[128593, 167071, ...|
# |      5|               [171]|[128593, 167071, ...|
# |      6|[7392, 102555, 10...|[128593, 167071, ...|
# |      8|             [44965]|[128593, 167071, ...|
# |      9|              [2507]|[128593, 167071, ...|
# |     10|             [46288]|[128593, 167071, ...|
# |     13|              [6897]|[128593, 167071, ...|
# |     14|[85069, 1544, 175...|[128593, 167071, ...|
# |     16|[6, 5, 21189, 10846]|[128593, 167071, ...|
# +-------+--------------------+--------------------+
# only showing top 10 rows

# %%
final_test_list=final_test.take(final_test.count())
final_test_list
# Out:
# [Row(User_ID=1, Recommend_Item_test=[5416, 45751, 1857, 33783], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=2, Recommend_Item_test=[2047], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=5, Recommend_Item_test=[171], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=6, Recommend_Item_test=[7392, 102555, 104722, 12887], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=8, Recommend_Item_test=[44965], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=9, Recommend_Item_test=[2507], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=10, Recommend_Item_test=[46288], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=13, Recommend_Item_test=[6897], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=14, Recommend_Item_test=[85069, 1544, 175, 14], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=16, Recommend_Item_test=[6, 5, 21189, 10846], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=17, Recommend_Item_test=[18242, 945, 97488, 512, 536, 27098, 33264], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=18, Recommend_Item_test=[46685, 5094], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=19, Recommend_Item_test=[6944], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=20, Recommend_Item_test=[1845, 68765], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=21, Recommend_Item_test=[7735], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=22, Recommend_Item_test=[4398], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=25, Recommend_Item_test=[1162], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=28, Recommend_Item_test=[384, 519], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=30, Recommend_Item_test=[127532], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=33, Recommend_Item_test=[1933], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=34, Recommend_Item_test=[4361, 4052, 2837], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=35, Recommend_Item_test=[94971], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=36, Recommend_Item_test=[4238, 582], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=37, Recommend_Item_test=[8120, 1628], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=38, Recommend_Item_test=[57645], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=40, Recommend_Item_test=[3522], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=42, Recommend_Item_test=[22541, 2536, 23698], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=44, Recommend_Item_test=[2409], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=47, Recommend_Item_test=[2389], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=51, Recommend_Item_test=[55677, 1079], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=52, Recommend_Item_test=[1114], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=53, Recommend_Item_test=[4131], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=54, Recommend_Item_test=[1849], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=55, Recommend_Item_test=[600, 4254, 17261, 29285, 451, 74996, 29610, 62020, 21], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=57, Recommend_Item_test=[1023, 54443, 7495], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=59, Recommend_Item_test=[1205], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=60, Recommend_Item_test=[23639, 3222], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=61, Recommend_Item_test=[22437, 279, 55786, 573, 35556, 38605, 21], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=62, Recommend_Item_test=[8785], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=63, Recommend_Item_test=[199, 302, 2679], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=64, Recommend_Item_test=[735], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=65, Recommend_Item_test=[1068], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=66, Recommend_Item_test=[159283], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=70, Recommend_Item_test=[9577], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=73, Recommend_Item_test=[40432, 934, 37492, 125487], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=75, Recommend_Item_test=[13337, 263, 86707], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=76, Recommend_Item_test=[2867, 18305], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=79, Recommend_Item_test=[7125], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=81, Recommend_Item_test=[27718, 972], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=82, Recommend_Item_test=[1316, 2332], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=83, Recommend_Item_test=[7, 68368, 21784, 1066, 52257, 295, 7814, 122444, 9251, 287], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=84, Recommend_Item_test=[770], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=86, Recommend_Item_test=[4872], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=89, Recommend_Item_test=[1794], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=94, Recommend_Item_test=[10176], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=95, Recommend_Item_test=[90609], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=97, Recommend_Item_test=[2], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=99, Recommend_Item_test=[4280], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=107, Recommend_Item_test=[62130], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=108, Recommend_Item_test=[1891], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=110, Recommend_Item_test=[390], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=113, Recommend_Item_test=[5366], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=115, Recommend_Item_test=[7802, 55711], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=116, Recommend_Item_test=[41858], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=119, Recommend_Item_test=[2130], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=120, Recommend_Item_test=[2118, 4057, 99, 29], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=125, Recommend_Item_test=[16827, 18424], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=129, Recommend_Item_test=[52250, 105999], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=130, Recommend_Item_test=[85, 3351], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=131, Recommend_Item_test=[405, 21613], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=132, Recommend_Item_test=[404, 25683], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=136, Recommend_Item_test=[26519], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=139, Recommend_Item_test=[2105], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=140, Recommend_Item_test=[20842], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=142, Recommend_Item_test=[31548], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=145, Recommend_Item_test=[91518], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=146, Recommend_Item_test=[5080, 8424], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=148, Recommend_Item_test=[452], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=149, Recommend_Item_test=[658], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=151, Recommend_Item_test=[110], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=155, Recommend_Item_test=[79033], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=156, Recommend_Item_test=[9302], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=158, Recommend_Item_test=[2123], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=159, Recommend_Item_test=[29121], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=160, Recommend_Item_test=[1151], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=161, Recommend_Item_test=[2293, 1734, 179, 39812, 34279, 16888], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=163, Recommend_Item_test=[453], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=164, Recommend_Item_test=[81509], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=166, Recommend_Item_test=[1278, 6436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=167, Recommend_Item_test=[18, 9422], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=168, Recommend_Item_test=[6769], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=169, Recommend_Item_test=[59547, 16644], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=170, Recommend_Item_test=[123], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=172, Recommend_Item_test=[123, 2762, 66793, 1878], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=173, Recommend_Item_test=[7142], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=176, Recommend_Item_test=[266, 30754], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=177, Recommend_Item_test=[1290], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=178, Recommend_Item_test=[25873], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=179, Recommend_Item_test=[449], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=180, Recommend_Item_test=[20982], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=181, Recommend_Item_test=[22], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=182, Recommend_Item_test=[13692], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=184, Recommend_Item_test=[46117], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=185, Recommend_Item_test=[9664, 95829], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=186, Recommend_Item_test=[36035], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=187, Recommend_Item_test=[74525, 47278, 663, 70, 15795], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=190, Recommend_Item_test=[5635, 1154], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=194, Recommend_Item_test=[9352, 104783], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=198, Recommend_Item_test=[4620], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=199, Recommend_Item_test=[4255], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=200, Recommend_Item_test=[93475], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=202, Recommend_Item_test=[8600, 8113], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=203, Recommend_Item_test=[329], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=204, Recommend_Item_test=[8], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=206, Recommend_Item_test=[14423, 203, 8149, 21732, 31194], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=208, Recommend_Item_test=[27455, 4588], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=210, Recommend_Item_test=[33009], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=211, Recommend_Item_test=[80436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=212, Recommend_Item_test=[159], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=213, Recommend_Item_test=[87], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=214, Recommend_Item_test=[44457], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=215, Recommend_Item_test=[18776, 13], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=217, Recommend_Item_test=[169882, 896], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=218, Recommend_Item_test=[57428], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=219, Recommend_Item_test=[2830], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=221, Recommend_Item_test=[11324, 14405, 18769], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=222, Recommend_Item_test=[6317, 762], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=223, Recommend_Item_test=[306], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=225, Recommend_Item_test=[595], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=226, Recommend_Item_test=[19164], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=228, Recommend_Item_test=[46417, 24985, 6341], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=230, Recommend_Item_test=[72, 27752], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=231, Recommend_Item_test=[40802, 5445], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=232, Recommend_Item_test=[3954, 3323, 104002], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=237, Recommend_Item_test=[62734, 1936], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=238, Recommend_Item_test=[46566, 190, 1219, 5881, 13628, 1681], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=239, Recommend_Item_test=[1199, 44505, 95, 91316, 94623, 2203], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=241, Recommend_Item_test=[3146], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=242, Recommend_Item_test=[1060], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=243, Recommend_Item_test=[6, 26130], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=244, Recommend_Item_test=[58], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=245, Recommend_Item_test=[1543, 426], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=246, Recommend_Item_test=[12904, 135880], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=247, Recommend_Item_test=[114547, 79405], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=250, Recommend_Item_test=[1821, 2344, 1147], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=252, Recommend_Item_test=[2563], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=253, Recommend_Item_test=[52583, 12126], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=254, Recommend_Item_test=[21376], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=256, Recommend_Item_test=[1397, 72251], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=257, Recommend_Item_test=[65348], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=258, Recommend_Item_test=[26375, 6696, 139299], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=259, Recommend_Item_test=[15555], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=262, Recommend_Item_test=[9928], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=263, Recommend_Item_test=[2902], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=264, Recommend_Item_test=[5606, 43121, 29405, 19987, 14658], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=265, Recommend_Item_test=[1581], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=267, Recommend_Item_test=[143605], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=268, Recommend_Item_test=[724, 111359], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=270, Recommend_Item_test=[45782], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=271, Recommend_Item_test=[125, 4612, 98190], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=272, Recommend_Item_test=[34716], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=273, Recommend_Item_test=[51386], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=274, Recommend_Item_test=[6589], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=278, Recommend_Item_test=[21630, 4975], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=279, Recommend_Item_test=[8], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=281, Recommend_Item_test=[73], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=285, Recommend_Item_test=[52387, 11], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=286, Recommend_Item_test=[474], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=287, Recommend_Item_test=[14538, 2956], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=290, Recommend_Item_test=[18075, 792], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=292, Recommend_Item_test=[3857, 111887, 26830], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=294, Recommend_Item_test=[12199, 7414, 96273], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=296, Recommend_Item_test=[20003], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=298, Recommend_Item_test=[3237], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=299, Recommend_Item_test=[9076, 282], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=300, Recommend_Item_test=[816], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=301, Recommend_Item_test=[129], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=302, Recommend_Item_test=[58379, 1399], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=304, Recommend_Item_test=[3574, 1920, 41381], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=307, Recommend_Item_test=[4637, 5533], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=309, Recommend_Item_test=[15179], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=310, Recommend_Item_test=[862], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=311, Recommend_Item_test=[1366], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=312, Recommend_Item_test=[21492, 111377, 76847], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=314, Recommend_Item_test=[175040], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=315, Recommend_Item_test=[1118, 294, 44148, 62], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=316, Recommend_Item_test=[1905, 914, 9703, 1603, 13035], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=318, Recommend_Item_test=[7900], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=319, Recommend_Item_test=[368], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=320, Recommend_Item_test=[102171], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=321, Recommend_Item_test=[770], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=322, Recommend_Item_test=[6701], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=324, Recommend_Item_test=[11791], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=325, Recommend_Item_test=[629, 11381, 43204, 12126, 436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=326, Recommend_Item_test=[12213], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=327, Recommend_Item_test=[22163], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=328, Recommend_Item_test=[39840], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=329, Recommend_Item_test=[44376], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=330, Recommend_Item_test=[2572], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=331, Recommend_Item_test=[13134], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=333, Recommend_Item_test=[7528], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=334, Recommend_Item_test=[8043, 5380], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=335, Recommend_Item_test=[17585], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=336, Recommend_Item_test=[17760], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=339, Recommend_Item_test=[9529, 43561], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=340, Recommend_Item_test=[108225, 14473], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=342, Recommend_Item_test=[8143], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=343, Recommend_Item_test=[40100], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=344, Recommend_Item_test=[117], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=345, Recommend_Item_test=[23773], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=346, Recommend_Item_test=[350], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=347, Recommend_Item_test=[1648, 1010], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=348, Recommend_Item_test=[25430, 36658, 5316, 125576, 393, 63535], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=352, Recommend_Item_test=[22673], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=354, Recommend_Item_test=[9063, 6591, 1, 4052], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=355, Recommend_Item_test=[45576], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=356, Recommend_Item_test=[94093, 2660], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=358, Recommend_Item_test=[188], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=359, Recommend_Item_test=[4292, 8763], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=360, Recommend_Item_test=[9213], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=363, Recommend_Item_test=[45647, 359], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=366, Recommend_Item_test=[25521, 8647, 119077], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=367, Recommend_Item_test=[307], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=370, Recommend_Item_test=[734, 63026, 850, 22985, 711, 964], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=371, Recommend_Item_test=[3684, 30], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=375, Recommend_Item_test=[36341], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=376, Recommend_Item_test=[2899], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=383, Recommend_Item_test=[3874], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=385, Recommend_Item_test=[2494, 566], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=387, Recommend_Item_test=[23], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=391, Recommend_Item_test=[61432, 542], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=392, Recommend_Item_test=[75], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=393, Recommend_Item_test=[6692], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=394, Recommend_Item_test=[329], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=395, Recommend_Item_test=[841], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=396, Recommend_Item_test=[1085, 128], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=397, Recommend_Item_test=[5086, 7619, 846, 75], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=398, Recommend_Item_test=[264], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=399, Recommend_Item_test=[48164, 44, 314], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=400, Recommend_Item_test=[56496, 126, 836, 10738, 573, 2904, 22948, 49357], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=403, Recommend_Item_test=[16845, 26484], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=405, Recommend_Item_test=[62033], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=407, Recommend_Item_test=[83254, 438], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=408, Recommend_Item_test=[15094, 1], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=409, Recommend_Item_test=[87771], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=412, Recommend_Item_test=[3905], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=413, Recommend_Item_test=[595, 684], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=414, Recommend_Item_test=[737], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=415, Recommend_Item_test=[136], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=420, Recommend_Item_test=[63473], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=421, Recommend_Item_test=[47518, 110409, 360], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=422, Recommend_Item_test=[19356, 14651], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=423, Recommend_Item_test=[124], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=425, Recommend_Item_test=[129782], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=429, Recommend_Item_test=[238], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=430, Recommend_Item_test=[4422], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=432, Recommend_Item_test=[16505, 22869], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=434, Recommend_Item_test=[6556], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=437, Recommend_Item_test=[20626], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=440, Recommend_Item_test=[25425, 97210], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=441, Recommend_Item_test=[3988, 573, 3683, 1904, 85901, 24975, 1958], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=442, Recommend_Item_test=[15102], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=445, Recommend_Item_test=[4794], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=447, Recommend_Item_test=[8375, 3091], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=450, Recommend_Item_test=[86014], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=451, Recommend_Item_test=[17850], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=452, Recommend_Item_test=[1996], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=453, Recommend_Item_test=[94049, 1364], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=454, Recommend_Item_test=[168718], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=456, Recommend_Item_test=[1084], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=457, Recommend_Item_test=[3168], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=458, Recommend_Item_test=[44551], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=461, Recommend_Item_test=[23208], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=462, Recommend_Item_test=[3627], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=463, Recommend_Item_test=[11064], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=464, Recommend_Item_test=[21869], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=465, Recommend_Item_test=[3067], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=467, Recommend_Item_test=[2919], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=469, Recommend_Item_test=[14861], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=470, Recommend_Item_test=[4384], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=471, Recommend_Item_test=[17832], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=474, Recommend_Item_test=[65488, 64667], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=475, Recommend_Item_test=[145447, 81442], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=476, Recommend_Item_test=[67724], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=479, Recommend_Item_test=[1643, 25401, 67752], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=480, Recommend_Item_test=[633], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=482, Recommend_Item_test=[10850], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=485, Recommend_Item_test=[117296], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=487, Recommend_Item_test=[9571], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=490, Recommend_Item_test=[3355, 14527], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=491, Recommend_Item_test=[882, 4615], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=492, Recommend_Item_test=[86742], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=494, Recommend_Item_test=[588], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=495, Recommend_Item_test=[93666], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=496, Recommend_Item_test=[130, 88041], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=497, Recommend_Item_test=[21102], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=498, Recommend_Item_test=[9405], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=499, Recommend_Item_test=[106314], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=500, Recommend_Item_test=[238], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=501, Recommend_Item_test=[2], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=502, Recommend_Item_test=[24007], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=503, Recommend_Item_test=[673], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=504, Recommend_Item_test=[2841, 86604], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=505, Recommend_Item_test=[27529], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=506, Recommend_Item_test=[11324, 106, 92903, 475], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=507, Recommend_Item_test=[26198, 3285, 70419], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=508, Recommend_Item_test=[2662], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=509, Recommend_Item_test=[2301], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=512, Recommend_Item_test=[13100, 27488], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=513, Recommend_Item_test=[5078, 5515], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=514, Recommend_Item_test=[46566, 17433, 249, 3855, 83533, 2], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=518, Recommend_Item_test=[6540, 6597], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=520, Recommend_Item_test=[2376], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=521, Recommend_Item_test=[13818, 1343, 11526, 1237, 33756, 5734, 6798, 751], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=523, Recommend_Item_test=[3662, 16119, 76682, 19896, 272], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=524, Recommend_Item_test=[22294], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=527, Recommend_Item_test=[190], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=528, Recommend_Item_test=[119050], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=529, Recommend_Item_test=[71309, 1850], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=530, Recommend_Item_test=[1697], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
# ...
#  Row(User_ID=1496, Recommend_Item_test=[744, 23545], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1498, Recommend_Item_test=[816, 8522, 2319, 11033, 173], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1499, Recommend_Item_test=[34271], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1501, Recommend_Item_test=[9432, 24211, 14282], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1503, Recommend_Item_test=[4264], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1506, Recommend_Item_test=[118], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1508, Recommend_Item_test=[79658], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1510, Recommend_Item_test=[98971], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1513, Recommend_Item_test=[10001], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1514, Recommend_Item_test=[12993], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1515, Recommend_Item_test=[14438], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1516, Recommend_Item_test=[1251, 200], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1521, Recommend_Item_test=[18262, 42941], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1527, Recommend_Item_test=[11613], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1528, Recommend_Item_test=[110104], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1530, Recommend_Item_test=[71306, 14135, 394], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1531, Recommend_Item_test=[5989, 1352], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1532, Recommend_Item_test=[74], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1534, Recommend_Item_test=[4135], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1535, Recommend_Item_test=[1484], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1537, Recommend_Item_test=[158, 32281, 35233, 291], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1538, Recommend_Item_test=[1118], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1539, Recommend_Item_test=[2603], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1540, Recommend_Item_test=[369, 12657], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1543, Recommend_Item_test=[53177], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1544, Recommend_Item_test=[30, 117], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1545, Recommend_Item_test=[47017, 1944, 10356, 11557], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1546, Recommend_Item_test=[41872], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1547, Recommend_Item_test=[5049, 18378, 6259, 29823, 16297], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1548, Recommend_Item_test=[1896], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1549, Recommend_Item_test=[1050, 12181, 45044, 87027], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1552, Recommend_Item_test=[33505], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1553, Recommend_Item_test=[1547, 3504], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1554, Recommend_Item_test=[10699], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1559, Recommend_Item_test=[735], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1560, Recommend_Item_test=[699, 714], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1563, Recommend_Item_test=[11], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1565, Recommend_Item_test=[170643], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1566, Recommend_Item_test=[1044], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1575, Recommend_Item_test=[8660, 56505], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1576, Recommend_Item_test=[29254, 27282], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1577, Recommend_Item_test=[105081, 45442, 4703], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1579, Recommend_Item_test=[29958], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1580, Recommend_Item_test=[19687, 134730], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1584, Recommend_Item_test=[9683], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1586, Recommend_Item_test=[49577], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1587, Recommend_Item_test=[43838, 81], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1589, Recommend_Item_test=[226, 1568, 54853], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1590, Recommend_Item_test=[24695], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1591, Recommend_Item_test=[95, 1248], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1595, Recommend_Item_test=[4591, 5, 49587], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1596, Recommend_Item_test=[1140], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1597, Recommend_Item_test=[8895], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1602, Recommend_Item_test=[19055, 26423], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1604, Recommend_Item_test=[361], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1607, Recommend_Item_test=[5293, 44391, 3651, 9398, 37832, 4078], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1608, Recommend_Item_test=[4629, 2301], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1611, Recommend_Item_test=[22803], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1612, Recommend_Item_test=[102267], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1614, Recommend_Item_test=[35151, 161540], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1615, Recommend_Item_test=[1267, 35809], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1617, Recommend_Item_test=[3640], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1619, Recommend_Item_test=[5134], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1620, Recommend_Item_test=[171, 707], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1623, Recommend_Item_test=[7174], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1625, Recommend_Item_test=[136436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1627, Recommend_Item_test=[9], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1631, Recommend_Item_test=[4812], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1632, Recommend_Item_test=[50529], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1633, Recommend_Item_test=[1504], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1634, Recommend_Item_test=[4577], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1636, Recommend_Item_test=[476], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1637, Recommend_Item_test=[105, 1736], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1639, Recommend_Item_test=[208, 15509, 13450], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1640, Recommend_Item_test=[133617], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1642, Recommend_Item_test=[19755], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1643, Recommend_Item_test=[12071], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1649, Recommend_Item_test=[339], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1650, Recommend_Item_test=[7506], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1652, Recommend_Item_test=[11792], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1656, Recommend_Item_test=[27436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1657, Recommend_Item_test=[907, 3], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1661, Recommend_Item_test=[803, 51758], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1663, Recommend_Item_test=[90218], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1664, Recommend_Item_test=[19810], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1666, Recommend_Item_test=[5318], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1668, Recommend_Item_test=[14315], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1669, Recommend_Item_test=[10641], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1670, Recommend_Item_test=[1277], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1671, Recommend_Item_test=[116053], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1672, Recommend_Item_test=[6589, 44515], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1680, Recommend_Item_test=[721], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1683, Recommend_Item_test=[141], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1684, Recommend_Item_test=[255, 18682], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1685, Recommend_Item_test=[6919], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1686, Recommend_Item_test=[15710], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1687, Recommend_Item_test=[99551], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1689, Recommend_Item_test=[72800], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1691, Recommend_Item_test=[575, 52601], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1692, Recommend_Item_test=[36279], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1693, Recommend_Item_test=[237, 8003], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1694, Recommend_Item_test=[423, 436], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1695, Recommend_Item_test=[9556], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1697, Recommend_Item_test=[15081, 1], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1699, Recommend_Item_test=[100100], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  Row(User_ID=1702, Recommend_Item_test=[2364], Recommend_Item_train=[128593, 167071, 93983, 114290, 143820, 70175, 78309, 70528, 113000, 98225]),
#  ...]

# %% [markdown]
# Count the true positive count of the baseline model

# %%
def recommend_count(*param):
    global final_test_list
    user_item=[param[0][0]]
    count=len(set(param[0][1])&set(param[0][2]))
    user_item.append(count)
    return user_item

# %%
recommend_num=[]
for i in range(len(final_test_list)):
    recommend_num.append(recommend_count(final_test_list[i]))

# %%
count=0
for i in range(len(recommend_num)):
    if recommend_num[i][1]!=0:
        count+=1
print(count)
# Out:
# 9
